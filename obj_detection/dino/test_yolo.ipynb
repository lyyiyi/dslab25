# %%
import os
import json
import torch
import numpy as np
import cv2
from ultralytics import YOLO
from PIL import Image
from IPython.display import display
from PIL import ImageDraw, ImageFont

# %%
# CONFIGURATION
repo_dir = os.getcwd().split('dslab25')[0] + 'dslab25/'
video_path = os.path.join(repo_dir, "assets/vacuum_pump/videos/01_run1_cam_2_1024x1024_15fps_3mbps.mp4")
labels_path = os.path.join(repo_dir, "assets/vacuum_pump/videos/output.txt")
coco_path = os.path.join(repo_dir, "training/vacuum_pump/coco_annotations.json")
# Path to your trained YOLOv12 weights (adjust as needed)
yolo_model_path = os.path.join(repo_dir, "obj_detection/dino/yolo_runs/yolov12_boundingbox", "weights", "best.pt")

def load_labels(labels_path):
	"""Load ground truth labels from file."""
	frame_to_class = {}
	with open(labels_path, 'r') as f:
		for line in f:
			parts = line.strip().split()
			if len(parts) == 3:
				state_class, start_frame, end_frame = int(parts[0]), int(parts[1]), int(parts[2])
				for frame_idx in range(start_frame, end_frame + 1):
					frame_to_class[frame_idx] = state_class
	return frame_to_class


# Load ground truth labels.
print(f"Loading labels from: {labels_path}")
frame_to_class = load_labels(labels_path)

# Load COCO annotations to map category IDs to names.
print(f"Loading COCO annotations from: {coco_path}")
try:
	with open(coco_path, 'r') as f:
		coco_data = json.load(f)
	category_id_to_name = {cat['id']: cat.get('name', f'category_{cat["id"]}')
								for cat in coco_data.get('categories', [])}
except (FileNotFoundError, json.JSONDecodeError) as e:
	print(f"Error loading COCO annotations: {e}")
	category_id_to_name = {}

# Load the YOLO model.
print("Loading YOLO model...")
yolo_model = YOLO(yolo_model_path)


# Optional: define a font for the label (if available)
try:
	font = ImageFont.truetype("arial.ttf", 16)
except IOError:
	font = ImageFont.load_default()
# Out:
# Loading labels from: /Users/georgye/Documents/repos/ethz/dslab25/assets/vacuum_pump/videos/output.txt
# Loading COCO annotations from: /Users/georgye/Documents/repos/ethz/dslab25/training/vacuum_pump/coco_annotations.json
# Loading YOLO model...

# %%
# Build a mapping from image_id to its ground truth category.
image_dir = os.path.join(repo_dir, "training/vacuum_pump/images/augmented/")
image_id_to_gt = {}
for ann in coco_data.get('annotations', []):
	image_id = ann['image_id']
	category_id = ann['category_id']
	image_id_to_gt[image_id] = category_id

# Use the defined image directory.
coco_images_dir = image_dir

print("\n--- Starting YOLO Evaluation on COCO Images with Bounding Boxes ---")
correct_predictions = 0
total_predictions = 0
# Iterate over each image defined in the COCO file.
for image_info in coco_data.get('images', []):
	image_id = image_info['id']
	file_name = image_info['file_name']
	image_path = os.path.join(coco_images_dir, file_name)
	
	if not os.path.exists(image_path):
		print(f"Image '{file_name}' not found in {coco_images_dir}. Skipping.")
		continue
		
	# Open the image and prepare for drawing.
	image = Image.open(image_path).convert("RGB")
	draw = ImageDraw.Draw(image)
	
	# Retrieve the ground truth category for the image.
	gt_category = image_id_to_gt.get(image_id)
	if gt_category is None:
		print(f"No ground truth annotation found for image ID {image_id}. Skipping.")
		continue
	
	# Convert the PIL image to a NumPy array in BGR format for YOLO.
	image_np = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
	
	# Run YOLO detection on the image.
	yolo_results = yolo_model(image_np)
	if len(yolo_results) == 0 or len(yolo_results[0].boxes) == 0:
		print(f"Image '{file_name}': No detection found. Skipping image.")
		continue
	
	# Retrieve detections and select the one with the highest confidence.
	boxes = yolo_results[0].boxes.data  # each row: [x1, y1, x2, y2, conf, cls]
	idx = torch.argmax(boxes[:, 4])
	box = boxes[idx]
	predicted_label = int(box[5].item())
	
	# Get bounding box coordinates and convert them to integer values.
	x1, y1, x2, y2 = box[:4].tolist()
	x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
	
	# Draw bounding box on the image.
	draw.rectangle(((x1, y1), (x2, y2)), outline="red", width=2)
	
	# Create a label text including predicted class name and confidence score.
	label_text = f"{category_id_to_name.get(predicted_label, f'Class_{predicted_label}')}: {box[4]:.2f}"
	
	# Compute text size using a fallback for compatibility.
	try:
		text_width, text_height = draw.textsize(label_text, font=font)
	except AttributeError:
		bbox = draw.textbbox((0, 0), label_text, font=font)
		text_width = bbox[2] - bbox[0]
		text_height = bbox[3] - bbox[1]
	
	# Draw a filled rectangle as background for the text.
	draw.rectangle([x1, y1, x1 + text_width, y1 + text_height], fill="red")
	draw.text((x1, y1), label_text, fill="white", font=font)
	
	# Map numeric labels to names for ground truth.
	gt_label_name = category_id_to_name.get(gt_category, f"Class_{gt_category}")
	predicted_label_name = category_id_to_name.get(predicted_label, f"Class_{predicted_label}")
	
	is_correct = predicted_label == gt_category
	if is_correct:
		correct_predictions += 1
	total_predictions += 1
	
	print(f"Image '{file_name}' (ID: {image_id}):")
	print(f"  True label: {gt_label_name} (ID: {gt_category})")
	print(f"  YOLO Predicted: {predicted_label_name} (ID: {predicted_label})")
	print(f"  Correct: {'Yes' if is_correct else 'No'}")
	print("-" * 20)
	
	# Display the image with the drawn bounding box.
	display(image)
	
accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
print("\nEvaluation Summary for COCO Images:")
print(f"  Total images evaluated: {total_predictions}")
print(f"  Correct predictions: {correct_predictions}")
print(f"  Accuracy: {accuracy:.2f} ({correct_predictions}/{total_predictions})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 image_dir = os.path.join(repo_dir, "training/vacuum_pump/images/augmented/")
#       3 image_id_to_gt = {}
# ----> 4 for ann in coco_data.get('annotations', []):
#       5 	image_id = ann['image_id']
#       6 	category_id = ann['category_id']
#
# NameError: name 'coco_data' is not defined

# %%
# Open the video.
print(f"Loading video from: {video_path}")
video = cv2.VideoCapture(video_path)
if not video.isOpened():
	raise Exception("Error: Could not open video file.")
	
total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
fps = video.get(cv2.CAP_PROP_FPS)
print(f"Video info: {total_frames} frames, {fps} fps")

print("\n--- Starting YOLO Evaluation ---")
frame_idx = 0
frames_to_process = []
# Process every 5th frame that has a ground truth label.
while True:
	ret, frame = video.read()
	if not ret:
		break
	if frame_idx % 5 == 0 and frame_idx in frame_to_class:
		frames_to_process.append((frame_idx, frame))
	frame_idx += 1
video.release()
print(f"Total frames to evaluate: {len(frames_to_process)}")

correct_predictions = 0
total_predictions = 0

for frame_idx, frame in frames_to_process:
	# Convert frame from BGR to RGB and then to PIL Image
	frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
	image = Image.fromarray(frame_rgb)
	draw = ImageDraw.Draw(image)
	

	true_label = frame_to_class[frame_idx]
	
	# Run YOLO detection on the frame.
	yolo_results = yolo_model(frame)
	if len(yolo_results) == 0 or len(yolo_results[0].boxes) == 0:
		print(f"Frame {frame_idx}: No detection found. Skipping frame.")
		continue
	
	# Retrieve detections and select the one with the highest confidence.
	boxes = yolo_results[0].boxes.data  # Each row: [x1, y1, x2, y2, conf, cls]
	idx = torch.argmax(boxes[:, 4])
	box = boxes[idx]
	
	# YOLO prediction: class is at index 5.
	predicted_label = int(box[5].item())
	
	# Map numeric labels to names (if available).
	true_label_name = category_id_to_name.get(true_label, f"Class_{true_label}")
	predicted_label_name = category_id_to_name.get(predicted_label, f"Class_{predicted_label}")
	
	# Get bounding box coordinates and convert them to integer values.
	x1, y1, x2, y2 = box[:4].tolist()
	x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
	
	# Draw bounding box on the image.
	draw.rectangle(((x1, y1), (x2, y2)), outline="red", width=2)
	
	# Create a label text including predicted class name and confidence score.
	label_text = f"{category_id_to_name.get(predicted_label, f'Class_{predicted_label}')}: {box[4]:.2f}"
	
	# Compute text size using a fallback for compatibility.
	try:
		text_width, text_height = draw.textsize(label_text, font=font)
	except AttributeError:
		bbox = draw.textbbox((0, 0), label_text, font=font)
		text_width = bbox[2] - bbox[0]
		text_height = bbox[3] - bbox[1]
	
	# Draw a filled rectangle as background for the text.
	draw.rectangle([x1, y1, x1 + text_width, y1 + text_height], fill="red")
	draw.text((x1, y1), label_text, fill="white", font=font)
	
	# Show the image frame in notebook
	display(image)
	
	is_correct = predicted_label == true_label
	if is_correct:
		correct_predictions += 1
	total_predictions += 1
	
	print(f"Frame {frame_idx}:")
	print(f"  True label: {true_label_name} (ID: {true_label})")
	print(f"  YOLO Predicted: {predicted_label_name} (ID: {predicted_label})")
	print(f"  Correct: {'Yes' if is_correct else 'No'}")
	print("-" * 20)

accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
print("\nEvaluation Summary:")
print(f"  Total frames evaluated: {total_predictions}")
print(f"  Correct predictions: {correct_predictions}")
print(f"  Accuracy: {accuracy:.2f} ({correct_predictions}/{total_predictions})")
# Out:
# Loading video from: /Users/georgye/Documents/repos/ethz/dslab25/assets/vacuum_pump/videos/01_run1_cam_2_1024x1024_15fps_3mbps.mp4
# Video info: 1856 frames, 15.0 fps
#
# --- Starting YOLO Evaluation ---
# Total frames to evaluate: 357
#
# 0: 640x640 2 stage_5s, 344.9ms
# Speed: 3.3ms preprocess, 344.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Frame 75:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 292.8ms
# Speed: 3.8ms preprocess, 292.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Frame 80:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 311.3ms
# Speed: 1.6ms preprocess, 311.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 85:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_0, 2 stage_5s, 296.4ms
# Speed: 1.8ms preprocess, 296.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 90:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_0 (ID: 0)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_0, 2 stage_5s, 282.2ms
# Speed: 1.7ms preprocess, 282.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 95:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_0 (ID: 0)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 280.1ms
# Speed: 1.6ms preprocess, 280.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Frame 100: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 267.0ms
# Speed: 2.2ms preprocess, 267.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 105:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 301.3ms
# Speed: 1.6ms preprocess, 301.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 110:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 271.1ms
# Speed: 2.1ms preprocess, 271.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 115: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 278.0ms
# Speed: 1.9ms preprocess, 278.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 120:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 284.3ms
# Speed: 1.7ms preprocess, 284.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Frame 125:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 270.3ms
# Speed: 1.8ms preprocess, 270.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 130:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 283.0ms
# Speed: 1.7ms preprocess, 283.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 135:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 278.8ms
# Speed: 2.0ms preprocess, 278.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 140:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 274.4ms
# Speed: 1.7ms preprocess, 274.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 145:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 277.4ms
# Speed: 1.6ms preprocess, 277.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 150:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 289.5ms
# Speed: 1.8ms preprocess, 289.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 155:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 283.1ms
# Speed: 1.7ms preprocess, 283.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 160:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 293.9ms
# Speed: 1.8ms preprocess, 293.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 165:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 288.7ms
# Speed: 1.7ms preprocess, 288.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 170:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 283.6ms
# Speed: 1.7ms preprocess, 283.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 175:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 287.0ms
# Speed: 1.8ms preprocess, 287.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 180:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 285.9ms
# Speed: 2.3ms preprocess, 285.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 185:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 291.8ms
# Speed: 1.9ms preprocess, 291.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 190:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 306.0ms
# Speed: 1.8ms preprocess, 306.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 195:
#   True label: stage_0 (ID: 0)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 281.6ms
# Speed: 1.7ms preprocess, 281.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 200:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_1s, 2 stage_5s, 296.7ms
# Speed: 1.8ms preprocess, 296.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 205:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_1 (ID: 1)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_1, 2 stage_5s, 347.0ms
# Speed: 1.8ms preprocess, 347.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 210:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_1 (ID: 1)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_1, 2 stage_5s, 281.5ms
# Speed: 1.6ms preprocess, 281.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 215:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_1 (ID: 1)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_5, 279.9ms
# Speed: 1.8ms preprocess, 279.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 220:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 278.5ms
# Speed: 3.4ms preprocess, 278.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 225:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 266.0ms
# Speed: 1.8ms preprocess, 266.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 230:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 3 stage_5s, 282.0ms
# Speed: 1.7ms preprocess, 282.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 235:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 301.3ms
# Speed: 1.7ms preprocess, 301.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 240:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 3 stage_5s, 296.7ms
# Speed: 1.9ms preprocess, 296.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 245:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 306.3ms
# Speed: 1.6ms preprocess, 306.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 250:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 296.3ms
# Speed: 1.8ms preprocess, 296.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 255:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 301.0ms
# Speed: 1.6ms preprocess, 301.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 260:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 300.1ms
# Speed: 1.8ms preprocess, 300.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 265:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 289.1ms
# Speed: 1.8ms preprocess, 289.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 270:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 302.7ms
# Speed: 1.6ms preprocess, 302.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 275:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 300.0ms
# Speed: 1.9ms preprocess, 300.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 280:
#   True label: stage_1 (ID: 1)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 295.4ms
# Speed: 2.5ms preprocess, 295.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 285:
#   True label: stage_2 (ID: 2)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 289.6ms
# Speed: 1.6ms preprocess, 289.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 290:
#   True label: stage_2 (ID: 2)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 296.8ms
# Speed: 2.5ms preprocess, 296.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 295:
#   True label: stage_2 (ID: 2)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 294.9ms
# Speed: 1.7ms preprocess, 294.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 300:
#   True label: stage_2 (ID: 2)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 276.2ms
# Speed: 3.5ms preprocess, 276.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Frame 305: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 280.9ms
# Speed: 1.7ms preprocess, 280.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 310: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 314.0ms
# Speed: 1.6ms preprocess, 314.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 315: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 290.5ms
# Speed: 2.8ms preprocess, 290.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Frame 320: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 278.3ms
# Speed: 1.7ms preprocess, 278.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 325: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 278.1ms
# Speed: 1.7ms preprocess, 278.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 330: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 313.6ms
# Speed: 1.7ms preprocess, 313.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 335: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 301.6ms
# Speed: 1.8ms preprocess, 301.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 340: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 373.7ms
# Speed: 1.8ms preprocess, 373.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 345: No detection found. Skipping frame.
#
# 0: 640x640 2 stage_5s, 283.8ms
# Speed: 3.9ms preprocess, 283.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 350:
#   True label: stage_3 (ID: 3)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 297.5ms
# Speed: 2.0ms preprocess, 297.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 355:
#   True label: stage_3 (ID: 3)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 303.3ms
# Speed: 3.0ms preprocess, 303.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 360:
#   True label: stage_3 (ID: 3)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 275.6ms
# Speed: 1.8ms preprocess, 275.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 365: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 279.4ms
# Speed: 1.8ms preprocess, 279.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 370:
#   True label: stage_3 (ID: 3)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 278.1ms
# Speed: 1.7ms preprocess, 278.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 375: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 307.8ms
# Speed: 1.9ms preprocess, 307.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 380: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 289.6ms
# Speed: 1.7ms preprocess, 289.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 385: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 297.1ms
# Speed: 1.8ms preprocess, 297.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 390: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 300.3ms
# Speed: 1.7ms preprocess, 300.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 395: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 280.7ms
# Speed: 6.9ms preprocess, 280.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 400:
#   True label: stage_4 (ID: 4)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 291.4ms
# Speed: 1.6ms preprocess, 291.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 405:
#   True label: stage_4 (ID: 4)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 293.2ms
# Speed: 1.8ms preprocess, 293.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 410: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 287.6ms
# Speed: 1.7ms preprocess, 287.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 415:
#   True label: stage_4 (ID: 4)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 301.7ms
# Speed: 1.8ms preprocess, 301.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 420:
#   True label: stage_4 (ID: 4)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 283.1ms
# Speed: 2.1ms preprocess, 283.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 425:
#   True label: stage_4 (ID: 4)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 299.3ms
# Speed: 1.7ms preprocess, 299.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 430:
#   True label: stage_4 (ID: 4)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 289.9ms
# Speed: 1.8ms preprocess, 289.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 435:
#   True label: stage_4 (ID: 4)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 287.1ms
# Speed: 1.6ms preprocess, 287.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 440:
#   True label: stage_4 (ID: 4)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 297.3ms
# Speed: 1.7ms preprocess, 297.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 445:
#   True label: stage_4 (ID: 4)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_5s, 291.5ms
# Speed: 1.9ms preprocess, 291.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 450:
#   True label: stage_4 (ID: 4)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 301.0ms
# Speed: 1.7ms preprocess, 301.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 455: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 286.4ms
# Speed: 1.7ms preprocess, 286.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 460: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 285.9ms
# Speed: 1.8ms preprocess, 285.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 465: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 298.5ms
# Speed: 2.0ms preprocess, 298.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 470: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 308.1ms
# Speed: 1.9ms preprocess, 308.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 475:
#   True label: stage_4 (ID: 4)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 300.7ms
# Speed: 1.7ms preprocess, 300.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 480: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 282.8ms
# Speed: 1.8ms preprocess, 282.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 485: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 304.4ms
# Speed: 3.0ms preprocess, 304.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 490: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 294.2ms
# Speed: 1.7ms preprocess, 294.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 495:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 2 stage_5s, 377.5ms
# Speed: 1.7ms preprocess, 377.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Frame 500:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 456.1ms
# Speed: 2.3ms preprocess, 456.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 505: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 394.0ms
# Speed: 1.9ms preprocess, 394.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 510: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 430.3ms
# Speed: 2.6ms preprocess, 430.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 515: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 761.5ms
# Speed: 2.1ms preprocess, 761.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 520: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 420.7ms
# Speed: 2.2ms preprocess, 420.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 525: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 305.9ms
# Speed: 1.7ms preprocess, 305.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Frame 530: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 295.5ms
# Speed: 1.8ms preprocess, 295.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 535: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 343.2ms
# Speed: 2.1ms preprocess, 343.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 540: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 374.5ms
# Speed: 1.9ms preprocess, 374.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 545: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 374.9ms
# Speed: 1.7ms preprocess, 374.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 550: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 685.9ms
# Speed: 2.4ms preprocess, 685.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 555: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 348.4ms
# Speed: 3.3ms preprocess, 348.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 560: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 310.3ms
# Speed: 1.9ms preprocess, 310.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 565: No detection found. Skipping frame.
#
# 0: 640x640 2 stage_5s, 339.3ms
# Speed: 2.0ms preprocess, 339.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 570:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 2 stage_5s, 341.8ms
# Speed: 2.0ms preprocess, 341.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 575:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 316.4ms
# Speed: 1.8ms preprocess, 316.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 580: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 438.6ms
# Speed: 2.4ms preprocess, 438.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 585: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 575.8ms
# Speed: 5.5ms preprocess, 575.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 590: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 358.2ms
# Speed: 2.8ms preprocess, 358.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 595: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 310.9ms
# Speed: 1.9ms preprocess, 310.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 600: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 391.7ms
# Speed: 2.5ms preprocess, 391.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 605: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 335.8ms
# Speed: 1.7ms preprocess, 335.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 610: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 323.0ms
# Speed: 1.6ms preprocess, 323.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 615:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 2 stage_5s, 371.7ms
# Speed: 2.5ms preprocess, 371.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 620:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_5, 348.3ms
# Speed: 3.3ms preprocess, 348.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 625:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_5, 320.2ms
# Speed: 1.6ms preprocess, 320.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 630:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_5, 319.5ms
# Speed: 1.6ms preprocess, 319.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Frame 635:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 358.9ms
# Speed: 1.8ms preprocess, 358.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 640: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 308.4ms
# Speed: 2.5ms preprocess, 308.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 645: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 315.4ms
# Speed: 1.6ms preprocess, 315.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 650:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 373.6ms
# Speed: 1.8ms preprocess, 373.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Frame 655: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 458.6ms
# Speed: 3.2ms preprocess, 458.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 660: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_0, 445.2ms
# Speed: 2.3ms preprocess, 445.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Frame 665:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_0 (ID: 0)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 340.2ms
# Speed: 1.8ms preprocess, 340.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 670: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 323.1ms
# Speed: 1.8ms preprocess, 323.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 675: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 452.9ms
# Speed: 1.7ms preprocess, 452.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 680: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 371.1ms
# Speed: 1.8ms preprocess, 371.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 685: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_0, 290.9ms
# Speed: 1.7ms preprocess, 290.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 690:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_0 (ID: 0)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_0, 291.1ms
# Speed: 1.7ms preprocess, 291.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 695:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_0 (ID: 0)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 313.4ms
# Speed: 1.6ms preprocess, 313.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 700:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 346.4ms
# Speed: 1.9ms preprocess, 346.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 705: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 278.0ms
# Speed: 4.6ms preprocess, 278.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 710: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 302.8ms
# Speed: 2.0ms preprocess, 302.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 715: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 305.9ms
# Speed: 1.7ms preprocess, 305.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 720: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 298.3ms
# Speed: 1.6ms preprocess, 298.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 725: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 335.9ms
# Speed: 2.4ms preprocess, 335.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Frame 730: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 446.5ms
# Speed: 2.5ms preprocess, 446.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 735: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 299.6ms
# Speed: 1.7ms preprocess, 299.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 740: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 319.3ms
# Speed: 1.7ms preprocess, 319.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 745: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 312.3ms
# Speed: 1.7ms preprocess, 312.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 750: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 291.8ms
# Speed: 1.7ms preprocess, 291.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 755: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 296.8ms
# Speed: 1.8ms preprocess, 296.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 760: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 294.3ms
# Speed: 1.7ms preprocess, 294.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 765: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 307.2ms
# Speed: 1.7ms preprocess, 307.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Frame 770: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 307.6ms
# Speed: 1.7ms preprocess, 307.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 775: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 303.1ms
# Speed: 1.7ms preprocess, 303.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 780: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 300.0ms
# Speed: 2.2ms preprocess, 300.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Frame 785: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 327.0ms
# Speed: 1.9ms preprocess, 327.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 790: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 427.4ms
# Speed: 2.1ms preprocess, 427.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 795: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 308.7ms
# Speed: 2.0ms preprocess, 308.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 800: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_3, 440.7ms
# Speed: 1.7ms preprocess, 440.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 805:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_3 (ID: 3)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_5, 370.5ms
# Speed: 5.4ms preprocess, 370.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 810:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 309.0ms
# Speed: 2.0ms preprocess, 309.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 815: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 311.0ms
# Speed: 3.0ms preprocess, 311.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Frame 820:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_5, 336.9ms
# Speed: 7.0ms preprocess, 336.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 825:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_5, 308.4ms
# Speed: 3.4ms preprocess, 308.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 830:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_5, 314.5ms
# Speed: 1.8ms preprocess, 314.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 835:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 298.7ms
# Speed: 1.8ms preprocess, 298.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 840: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 296.6ms
# Speed: 1.6ms preprocess, 296.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 845: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 295.4ms
# Speed: 1.9ms preprocess, 295.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 850: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 316.1ms
# Speed: 2.1ms preprocess, 316.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 855: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 402.8ms
# Speed: 3.0ms preprocess, 402.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 860: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 294.3ms
# Speed: 1.7ms preprocess, 294.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 865: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 309.6ms
# Speed: 1.8ms preprocess, 309.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Frame 870: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 293.5ms
# Speed: 2.4ms preprocess, 293.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Frame 875: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 326.2ms
# Speed: 2.3ms preprocess, 326.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 880: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 307.5ms
# Speed: 1.8ms preprocess, 307.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 885: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 303.5ms
# Speed: 6.2ms preprocess, 303.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 890: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 293.4ms
# Speed: 1.7ms preprocess, 293.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 895: No detection found. Skipping frame.
#
# 0: 640x640 3 stage_5s, 300.0ms
# Speed: 2.1ms preprocess, 300.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 900:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 303.4ms
# Speed: 2.2ms preprocess, 303.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 905: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 305.2ms
# Speed: 2.1ms preprocess, 305.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 910: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 292.4ms
# Speed: 1.7ms preprocess, 292.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 915: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 283.1ms
# Speed: 1.8ms preprocess, 283.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 920: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 318.0ms
# Speed: 1.7ms preprocess, 318.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 925: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 322.5ms
# Speed: 1.7ms preprocess, 322.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Frame 930: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 352.4ms
# Speed: 2.5ms preprocess, 352.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 935: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 439.4ms
# Speed: 2.0ms preprocess, 439.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 940: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 323.7ms
# Speed: 1.7ms preprocess, 323.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 945: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 279.3ms
# Speed: 2.6ms preprocess, 279.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Frame 950: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 333.7ms
# Speed: 1.7ms preprocess, 333.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 955: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 288.2ms
# Speed: 4.5ms preprocess, 288.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 960: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 309.1ms
# Speed: 2.2ms preprocess, 309.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 965: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 300.9ms
# Speed: 1.8ms preprocess, 300.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 970: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 334.5ms
# Speed: 1.6ms preprocess, 334.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 975: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 340.4ms
# Speed: 1.9ms preprocess, 340.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 980: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 310.4ms
# Speed: 1.6ms preprocess, 310.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 985: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 327.3ms
# Speed: 3.6ms preprocess, 327.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 990: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 311.3ms
# Speed: 4.6ms preprocess, 311.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 995: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 315.7ms
# Speed: 4.4ms preprocess, 315.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1000: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 311.1ms
# Speed: 2.3ms preprocess, 311.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1005: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 310.0ms
# Speed: 1.8ms preprocess, 310.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1010: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 313.2ms
# Speed: 1.7ms preprocess, 313.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1015: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 315.5ms
# Speed: 1.6ms preprocess, 315.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1020: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 302.5ms
# Speed: 2.8ms preprocess, 302.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1025: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 305.4ms
# Speed: 1.9ms preprocess, 305.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1030: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 291.2ms
# Speed: 2.0ms preprocess, 291.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1035: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 302.0ms
# Speed: 1.7ms preprocess, 302.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1040: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 408.5ms
# Speed: 2.2ms preprocess, 408.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1045: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 309.3ms
# Speed: 1.6ms preprocess, 309.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1050: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 315.3ms
# Speed: 1.6ms preprocess, 315.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1055: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 311.3ms
# Speed: 1.6ms preprocess, 311.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1060: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 343.7ms
# Speed: 1.8ms preprocess, 343.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1065: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 283.0ms
# Speed: 2.0ms preprocess, 283.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1070: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 332.7ms
# Speed: 1.6ms preprocess, 332.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1075:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_5, 295.3ms
# Speed: 1.7ms preprocess, 295.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1080:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 283.6ms
# Speed: 2.1ms preprocess, 283.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1085: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 294.3ms
# Speed: 3.8ms preprocess, 294.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1090:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_5, 299.9ms
# Speed: 2.0ms preprocess, 299.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1095:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 303.7ms
# Speed: 1.6ms preprocess, 303.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1100: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 285.8ms
# Speed: 1.6ms preprocess, 285.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1105: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 295.5ms
# Speed: 1.6ms preprocess, 295.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1110: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 309.5ms
# Speed: 1.6ms preprocess, 309.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1115: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 291.8ms
# Speed: 3.5ms preprocess, 291.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1120: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 301.7ms
# Speed: 1.6ms preprocess, 301.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1125:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 286.8ms
# Speed: 1.6ms preprocess, 286.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1130: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 280.9ms
# Speed: 1.7ms preprocess, 280.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1135: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 281.7ms
# Speed: 2.4ms preprocess, 281.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1140: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 288.0ms
# Speed: 1.7ms preprocess, 288.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1145:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 281.2ms
# Speed: 2.0ms preprocess, 281.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1150: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 278.4ms
# Speed: 1.7ms preprocess, 278.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1155: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 310.7ms
# Speed: 3.5ms preprocess, 310.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1160: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 278.1ms
# Speed: 1.9ms preprocess, 278.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1165: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 274.9ms
# Speed: 2.2ms preprocess, 274.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1170: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 289.2ms
# Speed: 1.7ms preprocess, 289.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1175: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 289.5ms
# Speed: 2.4ms preprocess, 289.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1180: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 312.5ms
# Speed: 3.9ms preprocess, 312.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1185: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 270.5ms
# Speed: 2.8ms preprocess, 270.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1190: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 290.9ms
# Speed: 1.6ms preprocess, 290.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1195: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 295.8ms
# Speed: 1.7ms preprocess, 295.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1200: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 275.1ms
# Speed: 1.6ms preprocess, 275.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1205: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 282.7ms
# Speed: 1.7ms preprocess, 282.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1210: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_5, 286.2ms
# Speed: 1.6ms preprocess, 286.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1215:
#   True label: stage_5 (ID: 5)
#   YOLO Predicted: stage_5 (ID: 5)
#   Correct: Yes
# --------------------
#
# 0: 640x640 (no detections), 300.2ms
# Speed: 1.8ms preprocess, 300.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1220: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 295.2ms
# Speed: 1.6ms preprocess, 295.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1225: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 297.3ms
# Speed: 1.6ms preprocess, 297.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1230: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 289.3ms
# Speed: 1.8ms preprocess, 289.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1235: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 285.7ms
# Speed: 2.1ms preprocess, 285.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1240: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 296.8ms
# ...
#
# 0: 640x640 (no detections), 285.2ms
# Speed: 1.7ms preprocess, 285.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1470: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 293.9ms
# Speed: 1.6ms preprocess, 293.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1475: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 287.3ms
# Speed: 2.0ms preprocess, 287.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1480: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 287.2ms
# Speed: 1.6ms preprocess, 287.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1485: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_0, 292.9ms
# Speed: 1.7ms preprocess, 292.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1490:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_0 (ID: 0)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 285.4ms
# Speed: 1.7ms preprocess, 285.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1495: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 303.1ms
# Speed: 1.6ms preprocess, 303.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1500: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_7, 303.5ms
# Speed: 1.7ms preprocess, 303.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1505:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_7 (ID: 7)
#   Correct: Yes
# --------------------
#
# 0: 640x640 1 stage_6, 291.9ms
# Speed: 3.1ms preprocess, 291.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1510:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 287.1ms
# Speed: 1.8ms preprocess, 287.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1515: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 272.1ms
# Speed: 1.8ms preprocess, 272.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1520: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 290.4ms
# Speed: 2.0ms preprocess, 290.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1525: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 299.8ms
# Speed: 1.6ms preprocess, 299.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1530: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 279.7ms
# Speed: 1.8ms preprocess, 279.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1535: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 282.5ms
# Speed: 2.1ms preprocess, 282.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1540: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 264.8ms
# Speed: 1.8ms preprocess, 264.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1545: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 317.4ms
# Speed: 1.7ms preprocess, 317.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1550: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 280.5ms
# Speed: 1.6ms preprocess, 280.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1555: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 303.9ms
# Speed: 2.7ms preprocess, 303.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1560: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 298.1ms
# Speed: 3.6ms preprocess, 298.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1565: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 299.6ms
# Speed: 8.8ms preprocess, 299.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1570: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 301.7ms
# Speed: 1.6ms preprocess, 301.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1575: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 267.8ms
# Speed: 6.5ms preprocess, 267.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1580: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 289.2ms
# Speed: 1.8ms preprocess, 289.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1585: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 285.4ms
# Speed: 2.5ms preprocess, 285.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1590: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 279.0ms
# Speed: 2.7ms preprocess, 279.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1595: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_6, 287.2ms
# Speed: 1.8ms preprocess, 287.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1600:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 294.8ms
# Speed: 1.6ms preprocess, 294.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1605:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 279.7ms
# Speed: 2.0ms preprocess, 279.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1610:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 286.5ms
# Speed: 1.6ms preprocess, 286.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1615:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 318.0ms
# Speed: 1.6ms preprocess, 318.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1620:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 285.4ms
# Speed: 10.2ms preprocess, 285.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1625: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 315.1ms
# Speed: 1.7ms preprocess, 315.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1630: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 314.7ms
# Speed: 1.8ms preprocess, 314.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1635: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 294.8ms
# Speed: 1.8ms preprocess, 294.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1640: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 289.2ms
# Speed: 2.5ms preprocess, 289.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1645: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 287.8ms
# Speed: 1.7ms preprocess, 287.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1650: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 281.9ms
# Speed: 1.7ms preprocess, 281.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1655: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 453.2ms
# Speed: 1.6ms preprocess, 453.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1660: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_0, 298.5ms
# Speed: 1.7ms preprocess, 298.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1665:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_0 (ID: 0)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 314.1ms
# Speed: 2.2ms preprocess, 314.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1670: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 327.3ms
# Speed: 3.4ms preprocess, 327.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1675: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 379.0ms
# Speed: 3.2ms preprocess, 379.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1680: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 328.4ms
# Speed: 3.0ms preprocess, 328.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1685: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 302.5ms
# Speed: 1.9ms preprocess, 302.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1690: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 321.6ms
# Speed: 1.9ms preprocess, 321.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1695: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 316.9ms
# Speed: 1.6ms preprocess, 316.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1700: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 329.3ms
# Speed: 2.1ms preprocess, 329.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1705: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 320.1ms
# Speed: 1.9ms preprocess, 320.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1710: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 311.1ms
# Speed: 1.7ms preprocess, 311.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1715: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_6, 287.7ms
# Speed: 2.4ms preprocess, 287.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1720:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 284.4ms
# Speed: 1.9ms preprocess, 284.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1725:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 284.2ms
# Speed: 1.7ms preprocess, 284.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1730:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 294.5ms
# Speed: 3.5ms preprocess, 294.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1735: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_6, 301.1ms
# Speed: 1.7ms preprocess, 301.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1740:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 301.6ms
# Speed: 1.7ms preprocess, 301.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1745:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 313.6ms
# Speed: 1.8ms preprocess, 313.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1750:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 293.4ms
# Speed: 1.7ms preprocess, 293.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1755:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 2 stage_6s, 290.6ms
# Speed: 1.6ms preprocess, 290.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1760:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 320.9ms
# Speed: 1.6ms preprocess, 320.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1765: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 320.0ms
# Speed: 2.1ms preprocess, 320.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1770: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_6, 312.0ms
# Speed: 1.7ms preprocess, 312.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1775:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 326.7ms
# Speed: 1.9ms preprocess, 326.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1780:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 (no detections), 329.6ms
# Speed: 1.9ms preprocess, 329.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1785: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 329.3ms
# Speed: 1.9ms preprocess, 329.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1790: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 306.3ms
# Speed: 1.8ms preprocess, 306.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1795: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 297.1ms
# Speed: 2.1ms preprocess, 297.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1800: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 304.4ms
# Speed: 1.7ms preprocess, 304.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1805: No detection found. Skipping frame.
#
# 0: 640x640 (no detections), 336.2ms
# Speed: 1.7ms preprocess, 336.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1810: No detection found. Skipping frame.
#
# 0: 640x640 1 stage_6, 303.4ms
# Speed: 2.3ms preprocess, 303.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1815:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 317.4ms
# Speed: 1.9ms preprocess, 317.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1820:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 316.2ms
# Speed: 1.9ms preprocess, 316.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1825:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 443.4ms
# Speed: 2.0ms preprocess, 443.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1830:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 352.7ms
# Speed: 1.9ms preprocess, 352.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1835:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 370.2ms
# Speed: 1.7ms preprocess, 370.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1840:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 326.7ms
# Speed: 3.0ms preprocess, 326.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1845:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 317.7ms
# Speed: 1.8ms preprocess, 317.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1850:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# 0: 640x640 1 stage_6, 303.5ms
# Speed: 1.8ms preprocess, 303.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1855:
#   True label: stage_7 (ID: 7)
#   YOLO Predicted: stage_6 (ID: 6)
#   Correct: No
# --------------------
#
# Evaluation Summary:
#   Total frames evaluated: 128
#   Correct predictions: 30
#   Accuracy: 0.23 (30/128)

# %%
import os
import re

def rename_render_files(folder_name):
	"""
	Goes through all subfolders of `folder_name`, finds files with 'render_<n>' in their name,
	and renames them to 'render_<n+9>'.
	"""
	pattern = re.compile(r'(.*_render_)(\d+)(\..+)$')

	for root, dirs, files in os.walk(folder_name):
		for filename in files:
			match = pattern.match(filename)
			if match:
				prefix, number_str, extension = match.groups()
				new_number = int(number_str) + 9
				new_filename = f"{prefix}{new_number}{extension}"

				old_path = os.path.join(root, filename)
				new_path = os.path.join(root, new_filename)

				os.rename(old_path, new_path)
				print(f"Renamed: {old_path} -> {new_path}")
rename_render_files('/Users/georgye/Documents/repos/ethz/dslab25/assets/vacuum_pump/rendered/anno')
