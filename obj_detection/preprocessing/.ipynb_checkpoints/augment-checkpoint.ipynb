# %%
import os
import cv2
import numpy as np 
import random
import math
import re
import shutil
import torch
import torchvision.transforms as T
import torchvision.transforms.functional as F

from torchvision import tv_tensors
from torchvision.transforms import v2, PILToTensor
from torchvision.transforms.functional import pil_to_tensor
from torchvision.io import read_image, write_jpeg
from torchvision.transforms.v2 import functional as F
from torchvision import tv_tensors

from PIL import Image

# %%
repo_dir = os.getcwd().split('dslab25')[0] + 'dslab25/'
root_dir = repo_dir + "training/vacuum_pump"
original_images = os.path.join(root_dir, "images/original")
original_annotations = os.path.join(root_dir, "annotation/original")
base_dir_images = os.path.join(root_dir, "images/augmented")
base_dir_annotations = os.path.join(root_dir, "annotation/augmented")
out_base_images = os.path.join(root_dir, "images/augmented")
out_base_annotations = os.path.join(root_dir, "annotation/augmented")

# %%
N_STAGES = 8

# %% [markdown]
# # Copy orignals to augmented folder

# %%
shutil.copytree(original_images, base_dir_images)
shutil.copytree(original_annotations, base_dir_annotations)
# Out:
# '/workspace/dslab25/training/vacuum_pump/annotation/augmented'

# %% [markdown]
# # Delete screw permutations (optional)

# %%
# def delete_non_hello_files(folder_path, perm_number_to_keep):
# 	"""
# 	Deletes all files in the specified folder that do not contain 'hello' in their name.
	
# 	Args:
# 		folder_path (str): Path to the target folder.
# 	"""
# 	if not os.path.isdir(folder_path):
# 		print(f"The path {folder_path} is not a valid directory.")
# 		return

# 	for filename in os.listdir(folder_path):
# 		file_path = os.path.join(folder_path, filename)
# 		if os.path.isfile(file_path) and perm_number_to_keep not in filename:
# 			try:
# 				os.remove(file_path)
# 				print(f"Deleted: {filename}")
# 			except Exception as e:
# 				print(f"Could not delete {filename}: {e}")
# delete_non_hello_files(os.path.join(base_dir_images, "stage_5"), "perm_7")
# delete_non_hello_files(os.path.join(base_dir_images, "stage_7"), "perm_31")

# %% [markdown]
# # Rotate (images takes up to 2 mins)

# %%
def rotate_image(image_path, out_image_path, out_annotation_path, angle):
	try:
		# Try using torchvision's read_image first
		try:
			image = read_image(image_path)
		except:
			# Fallback to PIL
			pil_image = Image.open(image_path).convert("RGB")
			image = PILToTensor()(pil_image)
		
		# Create rotation transformation with expand=True to avoid clipping
		transform = v2.Compose([
			v2.RandomRotation(degrees=(angle, angle), expand=True)
		])
		
		# Apply rotation to image
		rotated_image = transform(image)
		
		# Save rotated image
		write_jpeg(rotated_image, out_image_path, quality=95)
		
		# Create empty annotation file
		with open(out_annotation_path, 'w') as f:
			pass
			
		return True
	
	except Exception as e:
		print(f"Error processing {image_path}: {str(e)}")
		return False

stages = [f"stage_{i}" for i in range(N_STAGES)]
for stage in stages:
	image_folder = os.path.join(base_dir_images, stage)
	out_image_folder = os.path.join(out_base_images, stage)
	out_annotation_folder = os.path.join(out_base_annotations, stage)
		
	# Create output directories if they don't exist
	os.makedirs(out_image_folder, exist_ok=True)
	os.makedirs(out_annotation_folder, exist_ok=True)

	# List only original images (skip already augmented ones)
	image_files = [f for f in os.listdir(image_folder) if f.lower().endswith((".jpg", ".jpeg", ".png")) and "_rot" not in f]

	for filename in image_files:
		image_path = os.path.join(image_folder, filename)
		base_filename = os.path.splitext(filename)[0]

		# Apply rotations at 20° increments from 20° to 360°
		for angle in range(20, 361, 20):
			out_image_filename = f"{base_filename}_rot{angle}.jpg"
			out_annotation_filename = f"{base_filename}_rot{angle}.txt"
			out_image_path = os.path.join(out_image_folder, out_image_filename)
			out_annotation_path = os.path.join(out_annotation_folder, out_annotation_filename)

			success = rotate_image(image_path, out_image_path, out_annotation_path, angle)

			if success:
				print(f"Processed {out_image_path} with rotation {angle}°")
			else:
				print(f"Failed to process {image_path} with rotation {angle}°")
# Out:
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_1_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_2_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_3_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_1/stage_1_var_0_case_render_3_rot40.jpg with rotation 40°
# ...
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_3_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_4_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_5_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_6_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_7_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_8_rot360.jpg with rotation 360°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot20.jpg with rotation 20°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot40.jpg with rotation 40°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot60.jpg with rotation 60°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot80.jpg with rotation 80°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot100.jpg with rotation 100°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot120.jpg with rotation 120°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot140.jpg with rotation 140°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot160.jpg with rotation 160°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot180.jpg with rotation 180°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot200.jpg with rotation 200°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot220.jpg with rotation 220°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot240.jpg with rotation 240°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot260.jpg with rotation 260°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot280.jpg with rotation 280°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot300.jpg with rotation 300°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot320.jpg with rotation 320°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot340.jpg with rotation 340°
# Processed /workspace/dslab25/training/vacuum_pump/images/augmented/stage_7/stage_7_var_1_case_render_9_rot360.jpg with rotation 360°

# %% [markdown]
# # Rotate (labels correctly)

# %% [markdown]
# For this you need to label all 18 (360/20) rotations of render image 1, 2, 4

# %%
# Define the directories
BASE_LABELS_DIR = os.path.join(os.getcwd(), 'stage_0/labels/')

# Regular expressions for base and annotation files
base_pattern = re.compile(r'^stage_0_case_render_([124])_rot(\d+)\.txt$')
# For base we expect files: render_1, render_2, render_4.
# For the annotation files, we ignore any _perm_x part:
annot_pattern = re.compile(r'^stage_(\d+)(?:_perm_\d+)?(?:_var_\d+)?_case_render_(\d+)_rot(\d+)\.txt$')

# Data structure to hold rotation-specific base info
# key: rotation (as string), value: dict with base, col_shift, row_shift, w, h
rotation_data = {}

# First, process the base folder and group by rotation
# We need to read render_1, render_2, and render_4 for each rotation
for fname in os.listdir(BASE_LABELS_DIR):
	match = base_pattern.match(fname)
	if not match:
		continue
	render_number, rot = match.groups()
	path = os.path.join(BASE_LABELS_DIR, fname)
	with open(path, 'r') as f:
		# Assume each file has one line like "0 x y w h"
		parts = f.read().strip().split()
		# Convert numeric values (skip the class since we'll use our own later)
		# Order: class, x, y, w, h
		try:
			_, x, y, w, h = parts
			x, y, w, h = float(x), float(y), float(w), float(h)
		except Exception as e:
			print(f"Error processing {fname}: {e}")
			continue

	if rot not in rotation_data:
		rotation_data[rot] = {}
	rotation_data[rot][f'render_{render_number}'] = (x, y, w, h)

# Now, compute for each rotation the base values, col_shift and row_shift
for rot, data in rotation_data.items():
	try:
		base_x, base_y, w, h = data['render_1']
		col_x, col_y, _, _ = data['render_2']
		row_x, row_y, _, _ = data['render_4']
	except KeyError:
		print(f"Missing base files for rotation {rot}. Skipping.")
		continue

	# Calculate shifts
	col_shift = (col_x - base_x, col_y - base_y)
	row_shift = (row_x - base_x, row_y - base_y)
	# Save computed values back
	rotation_data[rot] = {
		'base': (base_x, base_y),
		'col_shift': col_shift,
		'row_shift': row_shift,
		'w': w,
		'h': h
	}

# Function to compute new coordinates given render number and rotation data
def compute_new_coords(render_num, rot_info):
	# Render number is expected as integer in 1..9, mapping to a 3x3 grid.
	# grid_x: how many times to add col_shift, grid_y: how many times to add row_shift.
	render_num = int(render_num)
	if render_num > 9:
		render_num -= 9 * (render_num // 9) + (render_num // 9 - 1)
	grid_x = (render_num - 1) % 3
	grid_y = (render_num - 1) // 3
	base_x, base_y = rot_info['base']
	col_shift_x, col_shift_y = rot_info['col_shift']
	row_shift_x, row_shift_y = rot_info['row_shift']

	new_x = base_x + grid_x * col_shift_x + grid_y * row_shift_x
	new_y = base_y + grid_x * col_shift_y + grid_y * row_shift_y
	return new_x, new_y

# Now, process each annotation file in the annotations folder
print(base_dir_annotations)
for stage_folder in os.listdir(base_dir_annotations):
	stage_path = os.path.join(base_dir_annotations, stage_folder)
	if not os.path.isdir(stage_path):
		continue
	# Expect folder name like stage_0, stage_1, etc.
	stage_match = re.match(r'stage_(\d+)', stage_folder)
	if not stage_match:
		continue
	class_id = stage_match.group(1)
	print("hm")
	# Process each file in the stage folder
	for fname in os.listdir(stage_path):
		annot_match = annot_pattern.match(fname)
		print(fname)
		if not annot_match:
			continue
		file_class, render_str, rot = annot_match.groups()
		# We ignore file_class (it might be redundant with the folder) and any perm parts
		if rot not in rotation_data:
			print(f"Rotation {rot} not found in base data for file {fname}. Skipping.")
			continue
		rot_info = rotation_data[rot]
		# Compute new x and y using the grid derived from render number
		new_x, new_y = compute_new_coords(render_str, rot_info)
		w = rot_info['w']
		h = rot_info['h']

		# Create new annotation line (class from folder, then new_x, new_y, w, h)
		new_line = f"{class_id} {new_x} {new_y} {w} {h}\n"
		# Overwrite the file
		out_path = os.path.join(stage_path, fname)
		with open(out_path, 'w') as f:
			f.write(new_line)
		print(f"Updated {out_path} with: {new_line.strip()}")
# Out:
# /workspace/dslab25/training/vacuum_pump/annotation/augmented
# hm
# stage_0_var_0_case_render_1.txt
# stage_0_var_0_case_render_2.txt
# stage_0_var_0_case_render_3.txt
# stage_0_var_0_case_render_4.txt
# stage_0_var_0_case_render_5.txt
# stage_0_var_0_case_render_6.txt
# stage_0_var_0_case_render_7.txt
# stage_0_var_0_case_render_8.txt
# stage_0_var_1_case_render_1.txt
# stage_0_var_1_case_render_2.txt
# stage_0_var_1_case_render_3.txt
# stage_0_var_1_case_render_4.txt
# stage_0_var_1_case_render_5.txt
# stage_0_var_1_case_render_6.txt
# stage_0_var_1_case_render_7.txt
# stage_0_var_1_case_render_8.txt
# stage_0_var_0_case_render_1_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot20.txt with: 0 0.41077507598784196 0.6520972644376899 0.2968237082066869 0.44673252279635256
# stage_0_var_0_case_render_1_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot40.txt with: 0 0.507202216066482 0.6540304709141274 0.2681163434903047 0.44117728531855954
# stage_0_var_0_case_render_1_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot60.txt with: 0 0.5801999999999999 0.6644857142857142 0.30484285714285714 0.45277142857142855
# stage_0_var_0_case_render_1_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot80.txt with: 0 0.632946127946128 0.6744107744107745 0.4257575757575758 0.4797979797979798
# stage_0_var_0_case_render_1_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot100.txt with: 0 0.6561952861952861 0.6387205387205387 0.4562289562289562 0.3683670033670034
# stage_0_var_0_case_render_1_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot120.txt with: 0 0.6510285714285715 0.5414714285714285 0.4322142857142857 0.275
# stage_0_var_0_case_render_1_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot140.txt with: 0 0.659972299168975 0.44973684210526316 0.44655124653739614 0.265595567867036
# stage_0_var_0_case_render_1_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot160.txt with: 0 0.6687234042553192 0.39714285714285713 0.4624012158054711 0.35914893617021276
# stage_0_var_0_case_render_1_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot180.txt with: 0 0.684453125 0.3312109375 0.498125 0.5078125
# stage_0_var_0_case_render_1_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot200.txt with: 0 0.5885410334346505 0.3455471124620061 0.2940273556231003 0.4431306990881459
# stage_0_var_0_case_render_1_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot220.txt with: 0 0.49498614958448756 0.34585872576177284 0.2681163434903047 0.43914127423822713
# stage_0_var_0_case_render_1_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot240.txt with: 0 0.4210714285714286 0.3371 0.30404285714285717 0.45515714285714287
# stage_0_var_0_case_render_1_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot260.txt with: 0 0.3688047138047138 0.32547138047138047 0.42015151515151516 0.47779461279461277
# stage_0_var_0_case_render_1_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot280.txt with: 0 0.34314814814814815 0.36175084175084177 0.4618350168350168 0.36917508417508416
# stage_0_var_0_case_render_1_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot300.txt with: 0 0.34924285714285713 0.4599142857142857 0.4334142857142857 0.2785714285714286
# stage_0_var_0_case_render_1_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot320.txt with: 0 0.3412049861495845 0.5507617728531856 0.44613573407202217 0.26886426592797785
# stage_0_var_0_case_render_1_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot340.txt with: 0 0.33177811550151975 0.6025075987841945 0.46200607902735563 0.3539361702127659
# stage_0_var_0_case_render_1_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_1_rot360.txt with: 0 0.31640625 0.669140625 0.494453125 0.50822265625
# stage_0_var_0_case_render_2_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot20.txt with: 0 0.5375531914893616 0.6061094224924012 0.2968237082066869 0.44673252279635256
# stage_0_var_0_case_render_2_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot40.txt with: 0 0.6015096952908587 0.5739750692520776 0.2681163434903047 0.44117728531855954
# stage_0_var_0_case_render_2_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot60.txt with: 0 0.6432857142857143 0.5531714285714286 0.30484285714285714 0.45277142857142855
# stage_0_var_0_case_render_2_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot80.txt with: 0 0.6581986531986532 0.5271043771043772 0.4257575757575758 0.4797979797979798
# stage_0_var_0_case_render_2_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot100.txt with: 0 0.6315488215488215 0.4922222222222222 0.4562289562289562 0.3683670033670034
# stage_0_var_0_case_render_2_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot120.txt with: 0 0.5861428571428572 0.43134285714285714 0.4322142857142857 0.275
# stage_0_var_0_case_render_2_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot140.txt with: 0 0.5634210526315789 0.3696814404432133 0.44655124653739614 0.265595567867036
# stage_0_var_0_case_render_2_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot160.txt with: 0 0.5415501519756839 0.35113981762917934 0.4624012158054711 0.35914893617021276
# stage_0_var_0_case_render_2_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot180.txt with: 0 0.5090625 0.3312109375 0.498125 0.5078125
# stage_0_var_0_case_render_2_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot200.txt with: 0 0.46656534954407297 0.3937386018237082 0.2940273556231003 0.4431306990881459
# stage_0_var_0_case_render_2_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot220.txt with: 0 0.39925207756232683 0.4252908587257618 0.2681163434903047 0.43914127423822713
# stage_0_var_0_case_render_2_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot240.txt with: 0 0.3577714285714286 0.44662857142857143 0.30404285714285717 0.45515714285714287
# stage_0_var_0_case_render_2_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot260.txt with: 0 0.34294612794612794 0.47297979797979794 0.42015151515151516 0.47779461279461277
# stage_0_var_0_case_render_2_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot280.txt with: 0 0.369006734006734 0.5084511784511784 0.4618350168350168 0.36917508417508416
# stage_0_var_0_case_render_2_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot300.txt with: 0 0.41471428571428576 0.5692428571428572 0.4334142857142857 0.2785714285714286
# stage_0_var_0_case_render_2_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot320.txt with: 0 0.4351108033240997 0.630803324099723 0.44613573407202217 0.26886426592797785
# stage_0_var_0_case_render_2_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot340.txt with: 0 0.4593617021276596 0.6491033434650456 0.46200607902735563 0.3539361702127659
# stage_0_var_0_case_render_2_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_2_rot360.txt with: 0 0.48953125 0.66751953125 0.494453125 0.50822265625
# stage_0_var_0_case_render_3_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot20.txt with: 0 0.6643313069908814 0.5601215805471125 0.2968237082066869 0.44673252279635256
# stage_0_var_0_case_render_3_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot40.txt with: 0 0.6958171745152355 0.4939196675900279 0.2681163434903047 0.44117728531855954
# stage_0_var_0_case_render_3_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot60.txt with: 0 0.7063714285714288 0.44185714285714306 0.30484285714285714 0.45277142857142855
# stage_0_var_0_case_render_3_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot80.txt with: 0 0.6834511784511784 0.3797979797979799 0.4257575757575758 0.4797979797979798
# stage_0_var_0_case_render_3_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot100.txt with: 0 0.6069023569023569 0.34572390572390577 0.4562289562289562 0.3683670033670034
# stage_0_var_0_case_render_3_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot120.txt with: 0 0.5212571428571429 0.3212142857142858 0.4322142857142857 0.275
# stage_0_var_0_case_render_3_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot140.txt with: 0 0.4668698060941828 0.2896260387811635 0.44655124653739614 0.265595567867036
# stage_0_var_0_case_render_3_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot160.txt with: 0 0.41437689969604863 0.30513677811550155 0.4624012158054711 0.35914893617021276
# stage_0_var_0_case_render_3_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot180.txt with: 0 0.33367187499999995 0.3312109375 0.498125 0.5078125
# stage_0_var_0_case_render_3_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot200.txt with: 0 0.34458966565349547 0.44193009118541027 0.2940273556231003 0.4431306990881459
# stage_0_var_0_case_render_3_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot220.txt with: 0 0.3035180055401661 0.5047229916897507 0.2681163434903047 0.43914127423822713
# stage_0_var_0_case_render_3_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot240.txt with: 0 0.29447142857142855 0.5561571428571428 0.30404285714285717 0.45515714285714287
# stage_0_var_0_case_render_3_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot260.txt with: 0 0.3170875420875421 0.6204882154882154 0.42015151515151516 0.47779461279461277
# stage_0_var_0_case_render_3_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot280.txt with: 0 0.39486531986531986 0.655151515151515 0.4618350168350168 0.36917508417508416
# stage_0_var_0_case_render_3_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot300.txt with: 0 0.4801857142857144 0.6785714285714286 0.4334142857142857 0.2785714285714286
# stage_0_var_0_case_render_3_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot320.txt with: 0 0.5290166204986149 0.7108448753462603 0.44613573407202217 0.26886426592797785
# stage_0_var_0_case_render_3_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot340.txt with: 0 0.5869452887537994 0.6956990881458968 0.46200607902735563 0.3539361702127659
# stage_0_var_0_case_render_3_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_3_rot360.txt with: 0 0.66265625 0.6658984374999999 0.494453125 0.50822265625
# stage_0_var_0_case_render_4_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot20.txt with: 0 0.3627811550151976 0.5285106382978724 0.2968237082066869 0.44673252279635256
# stage_0_var_0_case_render_4_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot40.txt with: 0 0.4261357340720222 0.5597229916897507 0.2681163434903047 0.44117728531855954
# stage_0_var_0_case_render_4_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot60.txt with: 0 0.4675 0.5998 0.30484285714285714 0.45277142857142855
# stage_0_var_0_case_render_4_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot80.txt with: 0 0.4836363636363636 0.6491582491582492 0.4257575757575758 0.4797979797979798
# stage_0_var_0_case_render_4_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot100.txt with: 0 0.5094949494949494 0.6635858585858586 0.4562289562289562 0.3683670033670034
# stage_0_var_0_case_render_4_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot120.txt with: 0 0.5397142857142857 0.6015857142857143 0.4322142857142857 0.275
# stage_0_var_0_case_render_4_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot140.txt with: 0 0.5801246537396122 0.5444459833795013 0.44655124653739614 0.265595567867036
# stage_0_var_0_case_render_4_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot160.txt with: 0 0.6213373860182371 0.5261094224924012 0.4624012158054711 0.35914893617021276
# stage_0_var_0_case_render_4_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot180.txt with: 0 0.684453125 0.50578125 0.498125 0.5078125
# stage_0_var_0_case_render_4_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot200.txt with: 0 0.6381306990881459 0.474726443768997 0.2940273556231003 0.4431306990881459
# stage_0_var_0_case_render_4_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot220.txt with: 0 0.573808864265928 0.43995844875346257 0.2681163434903047 0.43914127423822713
# stage_0_var_0_case_render_4_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot240.txt with: 0 0.5319857142857143 0.4008 0.30404285714285717 0.45515714285714287
# stage_0_var_0_case_render_4_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot260.txt with: 0 0.5187205387205387 0.35153198653198653 0.42015151515151516 0.47779461279461277
# stage_0_var_0_case_render_4_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot280.txt with: 0 0.4914646464646465 0.3358922558922559 0.4618350168350168 0.36917508417508416
# stage_0_var_0_case_render_4_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot300.txt with: 0 0.46214285714285713 0.3990142857142857 0.4334142857142857 0.2785714285714286
# stage_0_var_0_case_render_4_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot320.txt with: 0 0.42126038781163433 0.4546260387811634 0.44613573407202217 0.26886426592797785
# stage_0_var_0_case_render_4_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot340.txt with: 0 0.3779787234042553 0.4745288753799392 0.46200607902735563 0.3539361702127659
# stage_0_var_0_case_render_4_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_4_rot360.txt with: 0 0.31498046875 0.49296875 0.494453125 0.50822265625
# stage_0_var_0_case_render_5_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot20.txt with: 0 0.48955927051671727 0.48252279635258366 0.2968237082066869 0.44673252279635256
# stage_0_var_0_case_render_5_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot40.txt with: 0 0.520443213296399 0.479667590027701 0.2681163434903047 0.44117728531855954
# stage_0_var_0_case_render_5_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot60.txt with: 0 0.5305857142857144 0.4884857142857144 0.30484285714285714 0.45277142857142855
# stage_0_var_0_case_render_5_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot80.txt with: 0 0.5088888888888887 0.5018518518518519 0.4257575757575758 0.4797979797979798
# stage_0_var_0_case_render_5_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot100.txt with: 0 0.48484848484848486 0.5170875420875422 0.4562289562289562 0.3683670033670034
# stage_0_var_0_case_render_5_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot120.txt with: 0 0.4748285714285714 0.4914571428571429 0.4322142857142857 0.275
# stage_0_var_0_case_render_5_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot140.txt with: 0 0.4835734072022161 0.4643905817174515 0.44655124653739614 0.265595567867036
# stage_0_var_0_case_render_5_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot160.txt with: 0 0.4941641337386018 0.48010638297872343 0.4624012158054711 0.35914893617021276
# stage_0_var_0_case_render_5_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot180.txt with: 0 0.5090625 0.50578125 0.498125 0.5078125
# stage_0_var_0_case_render_5_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot200.txt with: 0 0.5161550151975685 0.522917933130699 0.2940273556231003 0.4431306990881459
# stage_0_var_0_case_render_5_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot220.txt with: 0 0.4780747922437673 0.5193905817174516 0.2681163434903047 0.43914127423822713
# stage_0_var_0_case_render_5_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot240.txt with: 0 0.46868571428571426 0.5103285714285715 0.30404285714285717 0.45515714285714287
# stage_0_var_0_case_render_5_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot260.txt with: 0 0.49286195286195283 0.499040404040404 0.42015151515151516 0.47779461279461277
# stage_0_var_0_case_render_5_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot280.txt with: 0 0.5173232323232324 0.4825925925925925 0.4618350168350168 0.36917508417508416
# stage_0_var_0_case_render_5_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot300.txt with: 0 0.5276142857142858 0.5083428571428572 0.4334142857142857 0.2785714285714286
# stage_0_var_0_case_render_5_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot320.txt with: 0 0.5151662049861495 0.5346675900277007 0.44613573407202217 0.26886426592797785
# stage_0_var_0_case_render_5_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot340.txt with: 0 0.5055623100303952 0.5211246200607904 0.46200607902735563 0.3539361702127659
# stage_0_var_0_case_render_5_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_5_rot360.txt with: 0 0.48810546875 0.49134765624999993 0.494453125 0.50822265625
# stage_0_var_0_case_render_6_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot20.txt with: 0 0.6163373860182371 0.43653495440729495 0.2968237082066869 0.44673252279635256
# stage_0_var_0_case_render_6_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot40.txt with: 0 0.6147506925207757 0.39961218836565127 0.2681163434903047 0.44117728531855954
# stage_0_var_0_case_render_6_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot60.txt with: 0 0.5936714285714288 0.3771714285714288 0.30484285714285714 0.45277142857142855
# stage_0_var_0_case_render_6_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot80.txt with: 0 0.534141414141414 0.3545454545454546 0.4257575757575758 0.4797979797979798
# stage_0_var_0_case_render_6_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot100.txt with: 0 0.4602020202020203 0.3705892255892257 0.4562289562289562 0.3683670033670034
# stage_0_var_0_case_render_6_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot120.txt with: 0 0.40994285714285705 0.38132857142857157 0.4322142857142857 0.275
# stage_0_var_0_case_render_6_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot140.txt with: 0 0.38702216066482 0.3843351800554017 0.44655124653739614 0.265595567867036
# stage_0_var_0_case_render_6_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot160.txt with: 0 0.3669908814589665 0.43410334346504564 0.4624012158054711 0.35914893617021276
# stage_0_var_0_case_render_6_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot180.txt with: 0 0.33367187499999995 0.50578125 0.498125 0.5078125
# stage_0_var_0_case_render_6_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot200.txt with: 0 0.3941793313069909 0.5711094224924012 0.2940273556231003 0.4431306990881459
# stage_0_var_0_case_render_6_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot220.txt with: 0 0.3823407202216066 0.5988227146814404 0.2681163434903047 0.43914127423822713
# stage_0_var_0_case_render_6_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot240.txt with: 0 0.40538571428571424 0.6198571428571428 0.30404285714285717 0.45515714285714287
# stage_0_var_0_case_render_6_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot260.txt with: 0 0.467003367003367 0.6465488215488215 0.42015151515151516 0.47779461279461277
# stage_0_var_0_case_render_6_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot280.txt with: 0 0.5431818181818182 0.6292929292929292 0.4618350168350168 0.36917508417508416
# stage_0_var_0_case_render_6_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot300.txt with: 0 0.5930857142857144 0.6176714285714286 0.4334142857142857 0.2785714285714286
# stage_0_var_0_case_render_6_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot320.txt with: 0 0.6090720221606647 0.614709141274238 0.44613573407202217 0.26886426592797785
# stage_0_var_0_case_render_6_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot340.txt with: 0 0.6331458966565349 0.5677203647416416 0.46200607902735563 0.3539361702127659
# stage_0_var_0_case_render_6_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_6_rot360.txt with: 0 0.6612304687499999 0.48972656249999985 0.494453125 0.50822265625
# stage_0_var_0_case_render_7_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot20.txt with: 0 0.3147872340425532 0.40492401215805485 0.2968237082066869 0.44673252279635256
# stage_0_var_0_case_render_7_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot40.txt with: 0 0.34506925207756245 0.46541551246537405 0.2681163434903047 0.44117728531855954
# stage_0_var_0_case_render_7_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot60.txt with: 0 0.3548000000000001 0.5351142857142858 0.30484285714285714 0.45277142857142855
# stage_0_var_0_case_render_7_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot80.txt with: 0 0.33432659932659914 0.6239057239057239 0.4257575757575758 0.4797979797979798
# stage_0_var_0_case_render_7_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot100.txt with: 0 0.3627946127946128 0.6884511784511785 0.4562289562289562 0.3683670033670034
# stage_0_var_0_case_render_7_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot120.txt with: 0 0.4283999999999999 0.6617000000000001 0.4322142857142857 0.275
# stage_0_var_0_case_render_7_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot140.txt with: 0 0.5002770083102493 0.6391551246537395 0.44655124653739614 0.265595567867036
# stage_0_var_0_case_render_7_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot160.txt with: 0 0.573951367781155 0.6550759878419453 0.4624012158054711 0.35914893617021276
# stage_0_var_0_case_render_7_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot180.txt with: 0 0.684453125 0.6803515624999998 0.498125 0.5078125
# stage_0_var_0_case_render_7_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot200.txt with: 0 0.6877203647416413 0.6039057750759879 0.2940273556231003 0.4431306990881459
# stage_0_var_0_case_render_7_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot220.txt with: 0 0.6526315789473685 0.5340581717451522 0.2681163434903047 0.43914127423822713
# stage_0_var_0_case_render_7_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot240.txt with: 0 0.6429 0.46449999999999997 0.30404285714285717 0.45515714285714287
# stage_0_var_0_case_render_7_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot260.txt with: 0 0.6686363636363636 0.3775925925925926 0.42015151515151516 0.47779461279461277
# stage_0_var_0_case_render_7_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot280.txt with: 0 0.6397811447811448 0.31003367003367005 0.4618350168350168 0.36917508417508416
# stage_0_var_0_case_render_7_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot300.txt with: 0 0.5750428571428572 0.3381142857142857 0.4334142857142857 0.2785714285714286
# stage_0_var_0_case_render_7_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot320.txt with: 0 0.5013157894736842 0.3584903047091412 0.44613573407202217 0.26886426592797785
# stage_0_var_0_case_render_7_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot340.txt with: 0 0.42417933130699087 0.34655015197568395 0.46200607902735563 0.3539361702127659
# stage_0_var_0_case_render_7_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_7_rot360.txt with: 0 0.31355468750000004 0.316796875 0.494453125 0.50822265625
# stage_0_var_0_case_render_8_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot20.txt with: 0 0.4415653495440729 0.35893617021276614 0.2968237082066869 0.44673252279635256
# stage_0_var_0_case_render_8_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot40.txt with: 0 0.4393767313019392 0.38536011080332433 0.2681163434903047 0.44117728531855954
# stage_0_var_0_case_render_8_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot60.txt with: 0 0.4178857142857145 0.4238000000000002 0.30484285714285714 0.45277142857142855
# stage_0_var_0_case_render_8_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot80.txt with: 0 0.35957912457912433 0.4765993265993266 0.4257575757575758 0.4797979797979798
# stage_0_var_0_case_render_8_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot100.txt with: 0 0.3381481481481482 0.5419528619528621 0.4562289562289562 0.3683670033670034
# stage_0_var_0_case_render_8_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot120.txt with: 0 0.36351428571428557 0.5515714285714287 0.4322142857142857 0.275
# stage_0_var_0_case_render_8_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot140.txt with: 0 0.40372576177285324 0.5590997229916896 0.44655124653739614 0.265595567867036
# stage_0_var_0_case_render_8_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot160.txt with: 0 0.4467781155015197 0.6090729483282675 0.4624012158054711 0.35914893617021276
# stage_0_var_0_case_render_8_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot180.txt with: 0 0.5090625 0.6803515624999998 0.498125 0.5078125
# stage_0_var_0_case_render_8_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot200.txt with: 0 0.5657446808510638 0.6520972644376899 0.2940273556231003 0.4431306990881459
# stage_0_var_0_case_render_8_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot220.txt with: 0 0.5568975069252078 0.6134903047091412 0.2681163434903047 0.43914127423822713
# stage_0_var_0_case_render_8_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot240.txt with: 0 0.5795999999999999 0.5740285714285713 0.30404285714285717 0.45515714285714287
# stage_0_var_0_case_render_8_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot260.txt with: 0 0.6427777777777777 0.5251010101010101 0.42015151515151516 0.47779461279461277
# stage_0_var_0_case_render_8_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot280.txt with: 0 0.6656397306397307 0.45673400673400666 0.4618350168350168 0.36917508417508416
# stage_0_var_0_case_render_8_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot300.txt with: 0 0.6405142857142858 0.44744285714285714 0.4334142857142857 0.2785714285714286
# stage_0_var_0_case_render_8_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot320.txt with: 0 0.5952216066481993 0.43853185595567856 0.44613573407202217 0.26886426592797785
# stage_0_var_0_case_render_8_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot340.txt with: 0 0.5517629179331307 0.3931458966565351 0.46200607902735563 0.3539361702127659
# stage_0_var_0_case_render_8_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_8_rot360.txt with: 0 0.4866796875 0.3151757812499999 0.494453125 0.50822265625
# stage_0_var_0_case_render_9_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot20.txt with: 0 0.5683434650455926 0.3129483282674774 0.2968237082066869 0.44673252279635256
# stage_0_var_0_case_render_9_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot40.txt with: 0 0.533684210526316 0.3053047091412746 0.2681163434903047 0.44117728531855954
# stage_0_var_0_case_render_9_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot60.txt with: 0 0.48097142857142894 0.3124857142857146 0.30484285714285714 0.45277142857142855
# stage_0_var_0_case_render_9_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot80.txt with: 0 0.3848316498316495 0.3292929292929293 0.4257575757575758 0.4797979797979798
# stage_0_var_0_case_render_9_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot100.txt with: 0 0.3135016835016836 0.3954545454545456 0.4562289562289562 0.3683670033670034
# stage_0_var_0_case_render_9_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot120.txt with: 0 0.29862857142857124 0.44144285714285736 0.4322142857142857 0.275
# stage_0_var_0_case_render_9_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot140.txt with: 0 0.30717451523545714 0.47904432132963987 0.44655124653739614 0.265595567867036
# stage_0_var_0_case_render_9_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot160.txt with: 0 0.3196048632218844 0.5630699088145897 0.4624012158054711 0.35914893617021276
# stage_0_var_0_case_render_9_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot180.txt with: 0 0.33367187499999995 0.6803515624999998 0.498125 0.5078125
# stage_0_var_0_case_render_9_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot200.txt with: 0 0.44376899696048633 0.700288753799392 0.2940273556231003 0.4431306990881459
# stage_0_var_0_case_render_9_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot220.txt with: 0 0.46116343490304706 0.6929224376731301 0.2681163434903047 0.43914127423822713
# stage_0_var_0_case_render_9_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot240.txt with: 0 0.5163 0.6835571428571428 0.30404285714285717 0.45515714285714287
# stage_0_var_0_case_render_9_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot260.txt with: 0 0.6169191919191919 0.6726094276094275 0.42015151515151516 0.47779461279461277
# stage_0_var_0_case_render_9_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot280.txt with: 0 0.6914983164983166 0.6034343434343433 0.4618350168350168 0.36917508417508416
# stage_0_var_0_case_render_9_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot300.txt with: 0 0.7059857142857144 0.5567714285714286 0.4334142857142857 0.2785714285714286
# stage_0_var_0_case_render_9_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot320.txt with: 0 0.6891274238227145 0.5185734072022159 0.44613573407202217 0.26886426592797785
# stage_0_var_0_case_render_9_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot340.txt with: 0 0.6793465045592705 0.43974164133738625 0.46200607902735563 0.3539361702127659
# stage_0_var_0_case_render_9_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_0_case_render_9_rot360.txt with: 0 0.6598046875 0.3135546874999998 0.494453125 0.50822265625
# stage_0_var_1_case_render_1_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot20.txt with: 0 0.41077507598784196 0.6520972644376899 0.2968237082066869 0.44673252279635256
# stage_0_var_1_case_render_1_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot40.txt with: 0 0.507202216066482 0.6540304709141274 0.2681163434903047 0.44117728531855954
# stage_0_var_1_case_render_1_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot60.txt with: 0 0.5801999999999999 0.6644857142857142 0.30484285714285714 0.45277142857142855
# stage_0_var_1_case_render_1_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot80.txt with: 0 0.632946127946128 0.6744107744107745 0.4257575757575758 0.4797979797979798
# stage_0_var_1_case_render_1_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot100.txt with: 0 0.6561952861952861 0.6387205387205387 0.4562289562289562 0.3683670033670034
# stage_0_var_1_case_render_1_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot120.txt with: 0 0.6510285714285715 0.5414714285714285 0.4322142857142857 0.275
# stage_0_var_1_case_render_1_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot140.txt with: 0 0.659972299168975 0.44973684210526316 0.44655124653739614 0.265595567867036
# stage_0_var_1_case_render_1_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot160.txt with: 0 0.6687234042553192 0.39714285714285713 0.4624012158054711 0.35914893617021276
# stage_0_var_1_case_render_1_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot180.txt with: 0 0.684453125 0.3312109375 0.498125 0.5078125
# stage_0_var_1_case_render_1_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot200.txt with: 0 0.5885410334346505 0.3455471124620061 0.2940273556231003 0.4431306990881459
# stage_0_var_1_case_render_1_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot220.txt with: 0 0.49498614958448756 0.34585872576177284 0.2681163434903047 0.43914127423822713
# stage_0_var_1_case_render_1_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot240.txt with: 0 0.4210714285714286 0.3371 0.30404285714285717 0.45515714285714287
# stage_0_var_1_case_render_1_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot260.txt with: 0 0.3688047138047138 0.32547138047138047 0.42015151515151516 0.47779461279461277
# stage_0_var_1_case_render_1_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot280.txt with: 0 0.34314814814814815 0.36175084175084177 0.4618350168350168 0.36917508417508416
# stage_0_var_1_case_render_1_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot300.txt with: 0 0.34924285714285713 0.4599142857142857 0.4334142857142857 0.2785714285714286
# stage_0_var_1_case_render_1_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot320.txt with: 0 0.3412049861495845 0.5507617728531856 0.44613573407202217 0.26886426592797785
# stage_0_var_1_case_render_1_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot340.txt with: 0 0.33177811550151975 0.6025075987841945 0.46200607902735563 0.3539361702127659
# stage_0_var_1_case_render_1_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_1_rot360.txt with: 0 0.31640625 0.669140625 0.494453125 0.50822265625
# stage_0_var_1_case_render_2_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot20.txt with: 0 0.5375531914893616 0.6061094224924012 0.2968237082066869 0.44673252279635256
# stage_0_var_1_case_render_2_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot40.txt with: 0 0.6015096952908587 0.5739750692520776 0.2681163434903047 0.44117728531855954
# stage_0_var_1_case_render_2_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot60.txt with: 0 0.6432857142857143 0.5531714285714286 0.30484285714285714 0.45277142857142855
# stage_0_var_1_case_render_2_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot80.txt with: 0 0.6581986531986532 0.5271043771043772 0.4257575757575758 0.4797979797979798
# stage_0_var_1_case_render_2_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot100.txt with: 0 0.6315488215488215 0.4922222222222222 0.4562289562289562 0.3683670033670034
# stage_0_var_1_case_render_2_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot120.txt with: 0 0.5861428571428572 0.43134285714285714 0.4322142857142857 0.275
# stage_0_var_1_case_render_2_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot140.txt with: 0 0.5634210526315789 0.3696814404432133 0.44655124653739614 0.265595567867036
# stage_0_var_1_case_render_2_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot160.txt with: 0 0.5415501519756839 0.35113981762917934 0.4624012158054711 0.35914893617021276
# stage_0_var_1_case_render_2_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot180.txt with: 0 0.5090625 0.3312109375 0.498125 0.5078125
# stage_0_var_1_case_render_2_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot200.txt with: 0 0.46656534954407297 0.3937386018237082 0.2940273556231003 0.4431306990881459
# stage_0_var_1_case_render_2_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot220.txt with: 0 0.39925207756232683 0.4252908587257618 0.2681163434903047 0.43914127423822713
# stage_0_var_1_case_render_2_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot240.txt with: 0 0.3577714285714286 0.44662857142857143 0.30404285714285717 0.45515714285714287
# stage_0_var_1_case_render_2_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot260.txt with: 0 0.34294612794612794 0.47297979797979794 0.42015151515151516 0.47779461279461277
# stage_0_var_1_case_render_2_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot280.txt with: 0 0.369006734006734 0.5084511784511784 0.4618350168350168 0.36917508417508416
# stage_0_var_1_case_render_2_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot300.txt with: 0 0.41471428571428576 0.5692428571428572 0.4334142857142857 0.2785714285714286
# stage_0_var_1_case_render_2_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot320.txt with: 0 0.4351108033240997 0.630803324099723 0.44613573407202217 0.26886426592797785
# stage_0_var_1_case_render_2_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot340.txt with: 0 0.4593617021276596 0.6491033434650456 0.46200607902735563 0.3539361702127659
# stage_0_var_1_case_render_2_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_2_rot360.txt with: 0 0.48953125 0.66751953125 0.494453125 0.50822265625
# stage_0_var_1_case_render_3_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_3_rot20.txt with: 0 0.6643313069908814 0.5601215805471125 0.2968237082066869 0.44673252279635256
# stage_0_var_1_case_render_3_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_3_rot40.txt with: 0 0.6958171745152355 0.4939196675900279 0.2681163434903047 0.44117728531855954
# stage_0_var_1_case_render_3_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_var_1_case_render_3_rot60.txt with: 0 0.7063714285714288 0.44185714285714306 0.30484285714285714 0.45277142857142855
# stage_0_var_1_case_render_3_rot80.txt
# ...
# stage_7_var_1_case_render_6_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot120.txt with: 7 0.40994285714285705 0.38132857142857157 0.4322142857142857 0.275
# stage_7_var_1_case_render_6_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot140.txt with: 7 0.38702216066482 0.3843351800554017 0.44655124653739614 0.265595567867036
# stage_7_var_1_case_render_6_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot160.txt with: 7 0.3669908814589665 0.43410334346504564 0.4624012158054711 0.35914893617021276
# stage_7_var_1_case_render_6_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot180.txt with: 7 0.33367187499999995 0.50578125 0.498125 0.5078125
# stage_7_var_1_case_render_6_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot200.txt with: 7 0.3941793313069909 0.5711094224924012 0.2940273556231003 0.4431306990881459
# stage_7_var_1_case_render_6_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot220.txt with: 7 0.3823407202216066 0.5988227146814404 0.2681163434903047 0.43914127423822713
# stage_7_var_1_case_render_6_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot240.txt with: 7 0.40538571428571424 0.6198571428571428 0.30404285714285717 0.45515714285714287
# stage_7_var_1_case_render_6_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot260.txt with: 7 0.467003367003367 0.6465488215488215 0.42015151515151516 0.47779461279461277
# stage_7_var_1_case_render_6_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot280.txt with: 7 0.5431818181818182 0.6292929292929292 0.4618350168350168 0.36917508417508416
# stage_7_var_1_case_render_6_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot300.txt with: 7 0.5930857142857144 0.6176714285714286 0.4334142857142857 0.2785714285714286
# stage_7_var_1_case_render_6_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot320.txt with: 7 0.6090720221606647 0.614709141274238 0.44613573407202217 0.26886426592797785
# stage_7_var_1_case_render_6_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot340.txt with: 7 0.6331458966565349 0.5677203647416416 0.46200607902735563 0.3539361702127659
# stage_7_var_1_case_render_6_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_6_rot360.txt with: 7 0.6612304687499999 0.48972656249999985 0.494453125 0.50822265625
# stage_7_var_1_case_render_7_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot20.txt with: 7 0.3147872340425532 0.40492401215805485 0.2968237082066869 0.44673252279635256
# stage_7_var_1_case_render_7_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot40.txt with: 7 0.34506925207756245 0.46541551246537405 0.2681163434903047 0.44117728531855954
# stage_7_var_1_case_render_7_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot60.txt with: 7 0.3548000000000001 0.5351142857142858 0.30484285714285714 0.45277142857142855
# stage_7_var_1_case_render_7_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot80.txt with: 7 0.33432659932659914 0.6239057239057239 0.4257575757575758 0.4797979797979798
# stage_7_var_1_case_render_7_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot100.txt with: 7 0.3627946127946128 0.6884511784511785 0.4562289562289562 0.3683670033670034
# stage_7_var_1_case_render_7_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot120.txt with: 7 0.4283999999999999 0.6617000000000001 0.4322142857142857 0.275
# stage_7_var_1_case_render_7_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot140.txt with: 7 0.5002770083102493 0.6391551246537395 0.44655124653739614 0.265595567867036
# stage_7_var_1_case_render_7_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot160.txt with: 7 0.573951367781155 0.6550759878419453 0.4624012158054711 0.35914893617021276
# stage_7_var_1_case_render_7_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot180.txt with: 7 0.684453125 0.6803515624999998 0.498125 0.5078125
# stage_7_var_1_case_render_7_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot200.txt with: 7 0.6877203647416413 0.6039057750759879 0.2940273556231003 0.4431306990881459
# stage_7_var_1_case_render_7_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot220.txt with: 7 0.6526315789473685 0.5340581717451522 0.2681163434903047 0.43914127423822713
# stage_7_var_1_case_render_7_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot240.txt with: 7 0.6429 0.46449999999999997 0.30404285714285717 0.45515714285714287
# stage_7_var_1_case_render_7_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot260.txt with: 7 0.6686363636363636 0.3775925925925926 0.42015151515151516 0.47779461279461277
# stage_7_var_1_case_render_7_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot280.txt with: 7 0.6397811447811448 0.31003367003367005 0.4618350168350168 0.36917508417508416
# stage_7_var_1_case_render_7_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot300.txt with: 7 0.5750428571428572 0.3381142857142857 0.4334142857142857 0.2785714285714286
# stage_7_var_1_case_render_7_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot320.txt with: 7 0.5013157894736842 0.3584903047091412 0.44613573407202217 0.26886426592797785
# stage_7_var_1_case_render_7_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot340.txt with: 7 0.42417933130699087 0.34655015197568395 0.46200607902735563 0.3539361702127659
# stage_7_var_1_case_render_7_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_7_rot360.txt with: 7 0.31355468750000004 0.316796875 0.494453125 0.50822265625
# stage_7_var_1_case_render_8_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot20.txt with: 7 0.4415653495440729 0.35893617021276614 0.2968237082066869 0.44673252279635256
# stage_7_var_1_case_render_8_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot40.txt with: 7 0.4393767313019392 0.38536011080332433 0.2681163434903047 0.44117728531855954
# stage_7_var_1_case_render_8_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot60.txt with: 7 0.4178857142857145 0.4238000000000002 0.30484285714285714 0.45277142857142855
# stage_7_var_1_case_render_8_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot80.txt with: 7 0.35957912457912433 0.4765993265993266 0.4257575757575758 0.4797979797979798
# stage_7_var_1_case_render_8_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot100.txt with: 7 0.3381481481481482 0.5419528619528621 0.4562289562289562 0.3683670033670034
# stage_7_var_1_case_render_8_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot120.txt with: 7 0.36351428571428557 0.5515714285714287 0.4322142857142857 0.275
# stage_7_var_1_case_render_8_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot140.txt with: 7 0.40372576177285324 0.5590997229916896 0.44655124653739614 0.265595567867036
# stage_7_var_1_case_render_8_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot160.txt with: 7 0.4467781155015197 0.6090729483282675 0.4624012158054711 0.35914893617021276
# stage_7_var_1_case_render_8_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot180.txt with: 7 0.5090625 0.6803515624999998 0.498125 0.5078125
# stage_7_var_1_case_render_8_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot200.txt with: 7 0.5657446808510638 0.6520972644376899 0.2940273556231003 0.4431306990881459
# stage_7_var_1_case_render_8_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot220.txt with: 7 0.5568975069252078 0.6134903047091412 0.2681163434903047 0.43914127423822713
# stage_7_var_1_case_render_8_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot240.txt with: 7 0.5795999999999999 0.5740285714285713 0.30404285714285717 0.45515714285714287
# stage_7_var_1_case_render_8_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot260.txt with: 7 0.6427777777777777 0.5251010101010101 0.42015151515151516 0.47779461279461277
# stage_7_var_1_case_render_8_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot280.txt with: 7 0.6656397306397307 0.45673400673400666 0.4618350168350168 0.36917508417508416
# stage_7_var_1_case_render_8_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot300.txt with: 7 0.6405142857142858 0.44744285714285714 0.4334142857142857 0.2785714285714286
# stage_7_var_1_case_render_8_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot320.txt with: 7 0.5952216066481993 0.43853185595567856 0.44613573407202217 0.26886426592797785
# stage_7_var_1_case_render_8_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot340.txt with: 7 0.5517629179331307 0.3931458966565351 0.46200607902735563 0.3539361702127659
# stage_7_var_1_case_render_8_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_8_rot360.txt with: 7 0.4866796875 0.3151757812499999 0.494453125 0.50822265625
# stage_7_var_1_case_render_9_rot20.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot20.txt with: 7 0.5683434650455926 0.3129483282674774 0.2968237082066869 0.44673252279635256
# stage_7_var_1_case_render_9_rot40.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot40.txt with: 7 0.533684210526316 0.3053047091412746 0.2681163434903047 0.44117728531855954
# stage_7_var_1_case_render_9_rot60.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot60.txt with: 7 0.48097142857142894 0.3124857142857146 0.30484285714285714 0.45277142857142855
# stage_7_var_1_case_render_9_rot80.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot80.txt with: 7 0.3848316498316495 0.3292929292929293 0.4257575757575758 0.4797979797979798
# stage_7_var_1_case_render_9_rot100.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot100.txt with: 7 0.3135016835016836 0.3954545454545456 0.4562289562289562 0.3683670033670034
# stage_7_var_1_case_render_9_rot120.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot120.txt with: 7 0.29862857142857124 0.44144285714285736 0.4322142857142857 0.275
# stage_7_var_1_case_render_9_rot140.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot140.txt with: 7 0.30717451523545714 0.47904432132963987 0.44655124653739614 0.265595567867036
# stage_7_var_1_case_render_9_rot160.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot160.txt with: 7 0.3196048632218844 0.5630699088145897 0.4624012158054711 0.35914893617021276
# stage_7_var_1_case_render_9_rot180.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot180.txt with: 7 0.33367187499999995 0.6803515624999998 0.498125 0.5078125
# stage_7_var_1_case_render_9_rot200.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot200.txt with: 7 0.44376899696048633 0.700288753799392 0.2940273556231003 0.4431306990881459
# stage_7_var_1_case_render_9_rot220.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot220.txt with: 7 0.46116343490304706 0.6929224376731301 0.2681163434903047 0.43914127423822713
# stage_7_var_1_case_render_9_rot240.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot240.txt with: 7 0.5163 0.6835571428571428 0.30404285714285717 0.45515714285714287
# stage_7_var_1_case_render_9_rot260.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot260.txt with: 7 0.6169191919191919 0.6726094276094275 0.42015151515151516 0.47779461279461277
# stage_7_var_1_case_render_9_rot280.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot280.txt with: 7 0.6914983164983166 0.6034343434343433 0.4618350168350168 0.36917508417508416
# stage_7_var_1_case_render_9_rot300.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot300.txt with: 7 0.7059857142857144 0.5567714285714286 0.4334142857142857 0.2785714285714286
# stage_7_var_1_case_render_9_rot320.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot320.txt with: 7 0.6891274238227145 0.5185734072022159 0.44613573407202217 0.26886426592797785
# stage_7_var_1_case_render_9_rot340.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot340.txt with: 7 0.6793465045592705 0.43974164133738625 0.46200607902735563 0.3539361702127659
# stage_7_var_1_case_render_9_rot360.txt
# Updated /workspace/dslab25/training/vacuum_pump/annotation/augmented/stage_7/stage_7_var_1_case_render_9_rot360.txt with: 7 0.6598046875 0.3135546874999998 0.494453125 0.50822265625

# %% [markdown]
# # SAM

# %%
from transformers import SamModel, SamProcessor

device = "cuda" if torch.cuda.is_available() else "cpu"

# Load the SAM model and processor.
model = SamModel.from_pretrained("facebook/sam-vit-huge").to(device)
processor = SamProcessor.from_pretrained("facebook/sam-vit-huge")
def pca_color_feature(feature_map, n_components=3):
    """
    Apply PCA to a feature map and reduce it to n_components (3 for RGB).

    Parameters:
      feature_map: a torch.Tensor of shape (channels, height, width)
      n_components: the number of PCA components (default is 3)

    Returns:
      A normalized image tensor of shape (height, width, n_components) with values in [0, 1].
    """
    # Rearrange feature_map to shape (height, width, channels)
    fm = feature_map.permute(1, 2, 0)   # (H, W, C)
    H, W, C = fm.shape

    # Flatten the spatial dimensions: shape -> (H*W, C)
    fm_flat = fm.reshape(-1, C)
    
    # Compute PCA using torch.pca_lowrank, reducing to n_components.
    # This returns U, S, V such that fm_flat ≈ U @ diag(S) @ V.T
    U, S, V = torch.pca_lowrank(fm_flat, q=n_components)
    
    # Project the flattened feature vectors onto the PCA space using V.
    # V has shape (C, n_components), so use:
    reduced = torch.matmul(fm_flat, V)  # shape: (H*W, n_components)
    
    # Reshape the reduced features back to (H, W, n_components)
    reduced = reduced.reshape(H, W, n_components)
    
    # Normalize each PCA channel to [0, 1] for display.
    flat_reduced = reduced.reshape(-1, n_components)
    min_vals = flat_reduced.min(dim=0)[0]
    max_vals = flat_reduced.max(dim=0)[0]
    normalized = (reduced - min_vals) / (max_vals - min_vals + 1e-5)

    return normalized

def display_edges_with_pca(image_path, output_file=None):
    """
    Load an image from disk, extract a feature map via SAM's image encoder,
    and use PCA to reduce the features to 3 channels (RGB). The result
    highlights edges and high-variance features.
    
    Parameters:
      image_path (str): Path to a jpg or png image.
      output_file (str, optional): Path where the output image will be saved.
                                   If None, the image is displayed.
    """
    
    # Load the image and convert it to RGB.
    raw_image = Image.open(image_path).convert("RGB")
    
    # Process the image using the processor.
    inputs = processor(raw_image, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    
    # Extract a feature map using the image encoder.
    with torch.no_grad():
        # Using get_image_embeddings is equivalent to calling the image encoder.
        feature_map = model.get_image_embeddings(inputs["pixel_values"])
    
    # Assume the output has shape (B, C, H, W); take the first image in the batch.
    feature_map = feature_map[0]  # shape: (C, H, W)
    
    # Apply PCA to the feature map to reduce it to 3 channels.
    pca_result = pca_color_feature(feature_map)  # shape: (H, W, 3)
    
    # Either save the image or show it.
    if output_file is not None:
        np_img = pca_result.cpu().detach().numpy()
        np_img = (np_img * 255).astype(np.uint8)

        # Resize PCA result to match original image resolution
        original_size = raw_image.size  # (width, height)
        np_img_resized = cv2.resize(np_img, original_size, interpolation=cv2.INTER_CUBIC)
        
        # Convert RGB -> BGR and save with OpenCV
        np_img_bgr = cv2.cvtColor(np_img_resized, cv2.COLOR_RGB2BGR)
        cv2.imwrite(output_file, np_img_bgr)
    else:
        # Create a figure and display the PCA-reduced feature map.
        plt.figure(figsize=(10, 10))
        plt.imshow(pca_result.cpu().detach().numpy())
        plt.title("PCA Reduced Feature Map (Edges Emphasized)")
        plt.axis("off")
        
        plt.show()

# Example usage:
# To save the output image:
# display_edges_with_pca("path/to/your/image.jpg", output_file="output_pca_image.png")
# To simply display the image:
# display_edges_with_pca("path/to/your/image.jpg")


	
# Process images in each stage.
stages = [f"stage_{i}" for i in range(N_STAGES)]
for stage in stages:
	in_image_folder = os.path.join(base_dir_images, stage)
	in_annotation_folder = os.path.join(base_dir_annotations, stage)
	out_image_folder = os.path.join(out_base_images, stage)
	out_annotation_folder = os.path.join(out_base_annotations, stage)
	
	os.makedirs(out_image_folder, exist_ok=True)
	os.makedirs(out_annotation_folder, exist_ok=True)
	
	# Select image files (filtering out already augmented ones that include "_translate").
	image_files = [f for f in os.listdir(in_image_folder)
				   if f.lower().endswith(".jpg") and "_sam" not in f]
	
	for filename in image_files:
		image_path = os.path.join(in_image_folder, filename)
		base_filename = os.path.splitext(filename)[0]
		annotation_filename = base_filename + ".txt"
		annotation_path = os.path.join(in_annotation_folder, annotation_filename)
		
		out_image_filename = f"{base_filename}_sam.jpg"
		out_annotation_filename = f"{base_filename}_sam.txt"
		out_image_path = os.path.join(out_image_folder, out_image_filename)
		out_annotation_path = os.path.join(out_annotation_folder, out_annotation_filename)
		
		# Apply the random translation augmentation.
		display_edges_with_pca(image_path, out_image_path)

		# Copy annotation unchanged.
		if os.path.exists(annotation_path):
			with open(annotation_path, 'r') as f:
				content = f.read()
			out_annotation_path = os.path.join(out_annotation_folder, f"{base_filename}_sam.txt")
			with open(out_annotation_path, 'w') as f:
				f.write(content)
		print(f"Processed sam augmentation: {out_image_path}")

# Example usage:
# Replace the path below with the location of your local image.
# display_edges_with_pca("path/to/your/image.jpg")
# Out:
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_3_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_4_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_5_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_6_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_7_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_8_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_9_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot20_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot40_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot60_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot80_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot100_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot120_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot140_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot160_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot180_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot200_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot220_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot240_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot260_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot280_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot300_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot320_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot340_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_1_rot360_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot20_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot40_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot60_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot80_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot100_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot120_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot140_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot160_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot180_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot200_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot220_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot240_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot260_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot280_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot300_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot320_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot340_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_2_rot360_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot20_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot40_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot60_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot80_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot100_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot120_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot140_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot160_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot180_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot200_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot220_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot240_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot260_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot280_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot300_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot320_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot340_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_3_rot360_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot20_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot40_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot60_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot80_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot100_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot120_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot140_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot160_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot180_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot200_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot220_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot240_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot260_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot280_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot300_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot320_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot340_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_4_rot360_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot20_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot40_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot60_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot80_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot100_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot120_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot140_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot160_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot180_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot200_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot220_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot240_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot260_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot280_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot300_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot320_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot340_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_5_rot360_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot20_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot40_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot60_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot80_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot100_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot120_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot140_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot160_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot180_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot200_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot220_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot240_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot260_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot280_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot300_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot320_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot340_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_6_rot360_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot20_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot40_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot60_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot80_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot100_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot120_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot140_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot160_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot180_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot200_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot220_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot240_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot260_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot280_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot300_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot320_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot340_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_7_rot360_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot20_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot40_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot60_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot80_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot100_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot120_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot140_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot160_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot180_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot200_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot220_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot240_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot260_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot280_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot300_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot320_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot340_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_8_rot360_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot20_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot40_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot60_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot80_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot100_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot120_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot140_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot160_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot180_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot200_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot220_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot240_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot260_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot280_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot300_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot320_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot340_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_0_case_render_9_rot360_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot20_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot40_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot60_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot80_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot100_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot120_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot140_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot160_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot180_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot200_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot220_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot240_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot260_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot280_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot300_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot320_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot340_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_1_rot360_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot20_sam.jpg
# Processed sam augmentation: /workspace/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_var_1_case_render_2_rot40_sam.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 131
#     128 out_annotation_path = os.path.join(out_annotation_folder, out_annotation_filename)
#     130 # Apply the random translation augmentation.
# --> 131 display_edges_with_pca(image_path, out_image_path)
#     133 # Copy annotation unchanged.
#     134 if os.path.exists(annotation_path):
#
# Cell In[10], line 61, in display_edges_with_pca(image_path, output_file)
#      58 raw_image = Image.open(image_path).convert("RGB")
#      60 # Process the image using the processor.
# ---> 61 inputs = processor(raw_image, return_tensors="pt")
#      62 inputs = {k: v.to(device) for k, v in inputs.items()}
#      64 # Extract a feature map using the image encoder.
#
# File /usr/local/lib/python3.11/dist-packages/transformers/models/sam/processing_sam.py:111, in SamProcessor.__call__(self, images, text, audio, video, *args, **kwargs)
#     108 input_boxes = output_kwargs["images_kwargs"].pop("input_boxes", None)
#     109 point_pad_value = output_kwargs["images_kwargs"].pop("point_pad_value", None)
# --> 111 encoding_image_processor = self.image_processor(
#     112     images,
#     113     **output_kwargs["images_kwargs"],
#     114 )
#     116 # pop arguments that are not used in the foward but used nevertheless
#     117 original_sizes = encoding_image_processor["original_sizes"]
#
# File /usr/local/lib/python3.11/dist-packages/transformers/image_processing_utils.py:42, in BaseImageProcessor.__call__(self, images, **kwargs)
#      40 def __call__(self, images, **kwargs) -> BatchFeature:
#      41     """Preprocess an image or a batch of images."""
# ---> 42     return self.preprocess(images, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:866, in filter_out_non_signature_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     857         cls_prefix = ""
#     859     warnings.warn(
#     860         f"The following named arguments are not valid for `{cls_prefix}{func.__name__}`"
#     861         f" and were ignored: {invalid_kwargs_names}",
#     862         UserWarning,
#     863         stacklevel=2,
#     864     )
# --> 866 return func(*args, **valid_kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/transformers/models/sam/image_processing_sam.py:521, in SamImageProcessor.preprocess(self, images, segmentation_maps, do_resize, size, mask_size, resample, do_rescale, rescale_factor, do_normalize, image_mean, image_std, do_pad, pad_size, mask_pad_size, do_convert_rgb, return_tensors, data_format, input_data_format)
#     504         raise ValueError(
#     505             "Invalid segmentation map type. Must be of type PIL.Image.Image, numpy.ndarray, "
#     506             "torch.Tensor, tf.Tensor or jax.ndarray."
#     507         )
#     508 validate_preprocess_arguments(
#     509     do_rescale=do_rescale,
#     510     rescale_factor=rescale_factor,
#    (...)
#     518     resample=resample,
#     519 )
# --> 521 images, original_sizes, reshaped_input_sizes = zip(
#     522     *(
#     523         self._preprocess_image(
#     524             image=img,
#     525             do_resize=do_resize,
#     526             size=size,
#     527             resample=resample,
#     528             do_rescale=do_rescale,
#     529             rescale_factor=rescale_factor,
#     530             do_normalize=do_normalize,
#     531             image_mean=image_mean,
#     532             image_std=image_std,
#     533             do_pad=do_pad,
#     534             pad_size=pad_size,
#     535             do_convert_rgb=do_convert_rgb,
#     536             data_format=data_format,
#     537             input_data_format=input_data_format,
#     538         )
#     539         for img in images
#     540     )
#     541 )
#     543 data = {
#     544     "pixel_values": images,
#     545     "original_sizes": original_sizes,
#     546     "reshaped_input_sizes": reshaped_input_sizes,
#     547 }
#     549 if segmentation_maps is not None:
#
# File /usr/local/lib/python3.11/dist-packages/transformers/models/sam/image_processing_sam.py:523, in <genexpr>(.0)
#     504         raise ValueError(
#     505             "Invalid segmentation map type. Must be of type PIL.Image.Image, numpy.ndarray, "
#     506             "torch.Tensor, tf.Tensor or jax.ndarray."
#     507         )
#     508 validate_preprocess_arguments(
#     509     do_rescale=do_rescale,
#     510     rescale_factor=rescale_factor,
#    (...)
#     518     resample=resample,
#     519 )
#     521 images, original_sizes, reshaped_input_sizes = zip(
#     522     *(
# --> 523         self._preprocess_image(
#     524             image=img,
#     525             do_resize=do_resize,
#     526             size=size,
#     527             resample=resample,
#     528             do_rescale=do_rescale,
#     529             rescale_factor=rescale_factor,
#     530             do_normalize=do_normalize,
#     531             image_mean=image_mean,
#     532             image_std=image_std,
#     533             do_pad=do_pad,
#     534             pad_size=pad_size,
#     535             do_convert_rgb=do_convert_rgb,
#     536             data_format=data_format,
#     537             input_data_format=input_data_format,
#     538         )
#     539         for img in images
#     540     )
#     541 )
#     543 data = {
#     544     "pixel_values": images,
#     545     "original_sizes": original_sizes,
#     546     "reshaped_input_sizes": reshaped_input_sizes,
#     547 }
#     549 if segmentation_maps is not None:
#
# File /usr/local/lib/python3.11/dist-packages/transformers/models/sam/image_processing_sam.py:328, in SamImageProcessor._preprocess_image(self, image, do_resize, size, resample, do_rescale, rescale_factor, do_normalize, image_mean, image_std, do_pad, pad_size, do_convert_rgb, data_format, input_data_format)
#     324     input_data_format = infer_channel_dimension_format(image)
#     326 original_size = get_image_size(image, channel_dim=input_data_format)
# --> 328 image, reshaped_input_size = self._preprocess(
#     329     image=image,
#     330     do_resize=do_resize,
#     331     size=size,
#     332     resample=resample,
#     333     do_rescale=do_rescale,
#     334     rescale_factor=rescale_factor,
#     335     do_normalize=do_normalize,
#     336     image_mean=image_mean,
#     337     image_std=image_std,
#     338     do_pad=do_pad,
#     339     pad_size=pad_size,
#     340     input_data_format=input_data_format,
#     341 )
#     343 if data_format is not None:
#     344     image = to_channel_dimension_format(image, data_format, input_channel_dim=input_data_format)
#
# File /usr/local/lib/python3.11/dist-packages/transformers/models/sam/image_processing_sam.py:283, in SamImageProcessor._preprocess(self, image, do_resize, do_rescale, do_normalize, size, resample, rescale_factor, image_mean, image_std, do_pad, pad_size, input_data_format)
#     280 reshaped_input_size = get_image_size(image, channel_dim=input_data_format)
#     282 if do_rescale:
# --> 283     image = self.rescale(image=image, scale=rescale_factor, input_data_format=input_data_format)
#     285 if do_normalize:
#     286     image = self.normalize(image=image, mean=image_mean, std=image_std, input_data_format=input_data_format)
#
# File /usr/local/lib/python3.11/dist-packages/transformers/image_processing_utils.py:77, in BaseImageProcessor.rescale(self, image, scale, data_format, input_data_format, **kwargs)
#      47 def rescale(
#      48     self,
#      49     image: np.ndarray,
#    (...)
#      53     **kwargs,
#      54 ) -> np.ndarray:
#      55     """
#      56     Rescale an image by a scale factor. image = image * scale.
#      57
#    (...)
#      75         `np.ndarray`: The rescaled image.
#      76     """
# ---> 77     return rescale(image, scale=scale, data_format=data_format, input_data_format=input_data_format, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/transformers/image_transforms.py:125, in rescale(image, scale, data_format, dtype, input_data_format)
#     122 if data_format is not None:
#     123     rescaled_image = to_channel_dimension_format(rescaled_image, data_format, input_data_format)
# --> 125 rescaled_image = rescaled_image.astype(dtype)  # Finally downcast to the desired dtype at the end
#     127 return rescaled_image
#
# KeyboardInterrupt:

# %% [markdown]
# # Tint patches

# %%
import cv2
import os
import numpy as np
import random

def tint_image_with_patches(image_path, annotation_path, out_image_path, out_annotation_path, patch_size=64, alpha=0.3):
	img = cv2.imread(image_path)
	if img is None:
		print("Failed to read image:", image_path)
		return
	
	h, w, _ = img.shape
	tinted_img = img.copy()

	# Iterate over image in 64x64 patches
	for y in range(0, h, patch_size):
		for x in range(0, w, patch_size):
			# Create random color
			color = np.array([random.randint(0, 255) for _ in range(3)], dtype=np.uint8)
			# Create a solid patch with the color
			color_patch = np.full((patch_size, patch_size, 3), color, dtype=np.uint8)

			# Define the region to blend
			end_y = min(y + patch_size, h)
			end_x = min(x + patch_size, w)

			# Blend original image and color patch
			region = tinted_img[y:end_y, x:end_x]
			blended = cv2.addWeighted(region, 1 - alpha, color_patch[:end_y - y, :end_x - x], alpha, 0)
			tinted_img[y:end_y, x:end_x] = blended

	cv2.imwrite(out_image_path, tinted_img)

	# Copy the annotation unchanged
	if os.path.exists(annotation_path):
		with open(annotation_path, 'r') as f:
			content = f.read()
		with open(out_annotation_path, 'w') as f:
			f.write(content)

tag = "colorpatch"
stages = [f"stage_{i}" for i in range(N_STAGES)]

for stage in stages:
	in_image_folder = os.path.join(base_dir_images, stage)
	in_annotation_folder = os.path.join(base_dir_annotations, stage)
	out_image_folder = os.path.join(out_base_images, stage)
	out_annotation_folder = os.path.join(out_base_annotations, stage)
	os.makedirs(out_image_folder, exist_ok=True)
	os.makedirs(out_annotation_folder, exist_ok=True)
	
	# Cache the list of original image files (skip those already augmented)
	image_files = [f for f in os.listdir(in_image_folder)
						if f.lower().endswith(".jpg") and "_bright" not in f and "_dark" not in f]
	
	for filename in image_files:
		image_path = os.path.join(in_image_folder, filename)
		base_filename = os.path.splitext(filename)[0]
		annotation_filename = base_filename + ".txt"
		annotation_path = os.path.join(in_annotation_folder, annotation_filename)

		out_image_filename = f"{base_filename}_{tag}.jpg"
		out_annotation_filename = f"{base_filename}_{tag}.txt"
		out_image_path = os.path.join(out_image_folder, out_image_filename)
		out_annotation_path = os.path.join(out_annotation_folder, out_annotation_filename)
		tint_image_with_patches(image_path, annotation_path, out_image_path, out_annotation_path)
		print(f"Processed color patch augmentation: {out_image_path}")

# %% [markdown]
# # Brightness

# %%
def adjust_brightness_and_copy_annotation(image_path, annotation_path, out_image_path, out_annotation_path, factor):
	img = cv2.imread(image_path)
	if img is None:
		print("Failed to read image:", image_path)
		return
	# Adjust brightness/darkness using cv2.convertScaleAbs.
	adjusted_img = cv2.convertScaleAbs(img, alpha=factor, beta=0)
	cv2.imwrite(out_image_path, adjusted_img)
	
	# Copy the annotation unchanged.
	if os.path.exists(annotation_path):
		with open(annotation_path, 'r') as f:
			content = f.read()
		with open(out_annotation_path, 'w') as f:
			f.write(content)

stages = [f"stage_{i}" for i in range(N_STAGES)]
# Define brightness augmentation factors.
brightness_aug = {
	"bright125": 1.5,
	"dark075": 0.5,
}

for stage in stages:
	in_image_folder = os.path.join(base_dir_images, stage)
	in_annotation_folder = os.path.join(base_dir_annotations, stage)
	out_image_folder = os.path.join(out_base_images, stage)
	out_annotation_folder = os.path.join(out_base_annotations, stage)
	os.makedirs(out_image_folder, exist_ok=True)
	os.makedirs(out_annotation_folder, exist_ok=True)
	
	# Cache the list of original image files (skip those already augmented)
	image_files = [f for f in os.listdir(in_image_folder)
						if f.lower().endswith(".jpg") and "_bright" not in f and "_dark" not in f]
	
	for filename in image_files:
		image_path = os.path.join(in_image_folder, filename)
		base_filename = os.path.splitext(filename)[0]
		annotation_filename = base_filename + ".txt"
		annotation_path = os.path.join(in_annotation_folder, annotation_filename)
				
		# Perform brightness/darkness augmentations.
		for tag, factor in brightness_aug.items():
			out_image_filename = f"{base_filename}_{tag}.jpg"
			out_annotation_filename = f"{base_filename}_{tag}.txt"
			out_image_path = os.path.join(out_image_folder, out_image_filename)
			out_annotation_path = os.path.join(out_annotation_folder, out_annotation_filename)
			adjust_brightness_and_copy_annotation(image_path, annotation_path, out_image_path, out_annotation_path, factor)
			print(f"Processed brightness augmentation: {out_image_path} with factor {factor}")

# %% [markdown]
# # Obscure

# %% [markdown]
# For each image in the base directories, read the corresponding annotation file,
# apply the obscure augmentation by drawing a random, smaller rectangle within each bounding box,
# and then save the resulting image and a copy of the annotation file in the output directories.

# %%
def obscure_object_in_image(image, annotation_path):
	"""
	For each bounding box (in YOLO format) in the given annotation file,
	draw a randomly sized and rotated rectangle inside the bounding box to obscure it.
	"""
	H, W = image.shape[:2]
	if not os.path.exists(annotation_path):
		return image

	with open(annotation_path, 'r') as f:
		lines = f.readlines()

	for line in lines:
		parts = line.strip().split()
		if len(parts) != 5:
			continue
		cls, cx, cy, bw, bh = parts
		cx, cy, bw, bh = float(cx), float(cy), float(bw), float(bh)
		
		# Calculate bounding box pixel coordinates.
		box_w = bw * W
		box_h = bh * H
		box_x1 = cx * W - box_w / 2
		box_y1 = cy * H - box_h / 2
		box_x2 = box_x1 + box_w
		box_y2 = box_y1 + box_h

		# Determine random scale factors for the inner (obscuring) rectangle.
		scale_w = random.uniform(0.1, 0.4)
		scale_h = random.uniform(0.1, 0.4)
		rect_w = box_w * scale_w
		rect_h = box_h * scale_h

		# Choose a random center for the inner rectangle ensuring it fits within the box.
		min_cx = box_x1 + rect_w / 2
		max_cx = box_x2 - rect_w / 2
		min_cy = box_y1 + rect_h / 2
		max_cy = box_y2 - rect_h / 2
		if max_cx < min_cx or max_cy < min_cy:
			rect_center_x = (box_x1 + box_x2) / 2
			rect_center_y = (box_y1 + box_y2) / 2
		else:
			rect_center_x = random.uniform(min_cx, max_cx)
			rect_center_y = random.uniform(min_cy, max_cy)

		# Determine a random rotation angle.
		angle = random.uniform(0, 360)

		# Create the rotated rectangle and get its corner points.
		rect = ((rect_center_x, rect_center_y), (rect_w, rect_h), angle)
		box_points = cv2.boxPoints(rect)
		box_points = box_points.astype(np.int32)

		# Draw a filled rectangle (using black color to obscure).
		cv2.fillPoly(image, [box_points], (0, 0, 0))
		
	return image


stages = [f"stage_{i}" for i in range(8)]

for stage in stages:
	in_image_folder = os.path.join(base_dir_images, stage)
	in_annotation_folder = os.path.join(base_dir_annotations, stage)
	out_image_folder = os.path.join(out_base_images, stage)
	out_annotation_folder = os.path.join(out_base_annotations, stage)
	os.makedirs(out_image_folder, exist_ok=True)
	os.makedirs(out_annotation_folder, exist_ok=True)
	
	# Cache the list of original image files (skip those already augmented).
	image_files = [f for f in os.listdir(in_image_folder)
						if f.lower().endswith(".jpg") and "_obscure" not in f]
	
	for filename in image_files:
		image_path = os.path.join(in_image_folder, filename)
		base_filename = os.path.splitext(filename)[0]
		annotation_filename = base_filename + ".txt"
		annotation_path = os.path.join(in_annotation_folder, annotation_filename)
		
		img = cv2.imread(image_path)
		if img is None:
			print("Failed to read image:", image_path)
			continue

		# Obscure objects in the image using their bounding boxes.
		obscured_img = obscure_object_in_image(img, annotation_path)
		out_image_filename = f"{base_filename}_obscure.jpg"
		out_image_path = os.path.join(out_image_folder, out_image_filename)
		cv2.imwrite(out_image_path, obscured_img)
		
		# Copy annotation unchanged.
		if os.path.exists(annotation_path):
			with open(annotation_path, 'r') as f:
				content = f.read()
			out_annotation_path = os.path.join(out_annotation_folder, f"{base_filename}_obscure.txt")
			with open(out_annotation_path, 'w') as f:
				f.write(content)
		print(f"Processed obscure augmentation: {out_image_path}")

# %% [markdown]
# # Scale

# %%
def random_scale_and_crop_annotation(image_path, annotation_path, out_image_path, out_annotation_path, scale_range=(1.0, 2.0)):
	"""
	Scales the image by a random factor and then crops the center region to 
	restore the original image size. Adjusts YOLO annotations accordingly.
	"""
	# Read the original image.
	img = cv2.imread(image_path)
	if img is None:
		print("Failed to read image:", image_path)
		return
	
	original_h, original_w = img.shape[:2]

	# Randomly select a scale factor.
	scale_factor = random.uniform(scale_range[0], scale_range[1])
	
	# Compute new dimensions for the scaled image.
	new_w = int(original_w * scale_factor)
	new_h = int(original_h * scale_factor)
	
	# Resize (scale) the image.
	scaled_img = cv2.resize(img, (new_w, new_h), interpolation=cv2.INTER_LINEAR)
	
	# Ensure the scaled image is large enough for the crop.
	if new_w < original_w or new_h < original_h:
		print("Scaled image is smaller than original; adjust scale_range or add padding.")
		return

	# Compute crop offsets to extract the center region.
	x_offset = (new_w - original_w) // 2
	y_offset = (new_h - original_h) // 2
	
	# Crop the center region.
	cropped_img = scaled_img[y_offset:y_offset + original_h, x_offset:x_offset + original_w]
	
	# Write the augmented image.
	cv2.imwrite(out_image_path, cropped_img)
	
	# Read and update the annotation file.
	# Assumption: annotations are in YOLO normalized format.
	adjusted_lines = []
	if os.path.exists(annotation_path):
		with open(annotation_path, 'r') as file:
			for line in file:
				parts = line.strip().split()
				if len(parts) == 5:
					class_id, cx, cy, bw, bh = parts
					cx = float(cx)
					cy = float(cy)
					bw = float(bw)
					bh = float(bh)
					
					# Convert normalized coordinates to absolute pixel coordinates in the original image.
					abs_cx = cx * original_w
					abs_cy = cy * original_h
					abs_bw = bw * original_w
					abs_bh = bh * original_h
					
					# Apply scaling.
					scaled_cx = abs_cx * scale_factor
					scaled_cy = abs_cy * scale_factor
					scaled_bw = abs_bw * scale_factor
					scaled_bh = abs_bh * scale_factor
					
					# Adjust for cropping by subtracting the offsets.
					cropped_cx = scaled_cx - x_offset
					cropped_cy = scaled_cy - y_offset
					
					# (Optional) If a bounding box falls partially outside,
					# you can clip the box here. For simplicity, we assume
					# the boxes are fully contained.
					
					# Convert back to normalized coordinates with respect to the output image dimensions.
					new_cx = cropped_cx / original_w
					new_cy = cropped_cy / original_h
					new_bw = scaled_bw / original_w
					new_bh = scaled_bh / original_h
					
					# Write the new annotation line.
					adjusted_line = f"{class_id} {new_cx:.6f} {new_cy:.6f} {new_bw:.6f} {new_bh:.6f}\n"
					adjusted_lines.append(adjusted_line)
				else:
					# For lines that do not match the expected format, copy them as is.
					adjusted_lines.append(line)
		# Save the adjusted annotations.
		with open(out_annotation_path, 'w') as file:
			file.writelines(adjusted_lines)
	
	print(f"Processed augmentation for {out_image_path}: scale factor {scale_factor:.2f}, crop offsets ({x_offset}, {y_offset})")

stages = [f"stage_{i}" for i in range(N_STAGES)]
for stage in stages:
	in_image_folder = os.path.join(base_dir_images, stage)
	in_annotation_folder = os.path.join(base_dir_annotations, stage)
	out_image_folder = os.path.join(out_base_images, stage)
	out_annotation_folder = os.path.join(out_base_annotations, stage)
	
	os.makedirs(out_image_folder, exist_ok=True)
	os.makedirs(out_annotation_folder, exist_ok=True)
	
	image_files = [f for f in os.listdir(in_image_folder)
				   if f.lower().endswith(".jpg") and "_scale" not in f]
	
	for filename in image_files:
		image_path = os.path.join(in_image_folder, filename)
		base_filename = os.path.splitext(filename)[0]
		annotation_filename = base_filename + ".txt"
		annotation_path = os.path.join(in_annotation_folder, annotation_filename)
		
		out_image_filename = f"{base_filename}_scale.jpg"
		out_annotation_filename = f"{base_filename}_scale.txt"
		out_image_path = os.path.join(out_image_folder, out_image_filename)
		out_annotation_path = os.path.join(out_annotation_folder, out_annotation_filename)
		
		random_scale_and_crop_annotation(image_path, annotation_path, out_image_path, out_annotation_path)

# %% [markdown]
# # Translate

# %%
def random_translate_and_update_annotation(image_path, annotation_path, out_image_path, out_annotation_path):
	"""
	Applies a random translation to the image and updates the annotation coordinates accordingly.
	
	The translation is random:
	  - x direction: uniformly chosen from -1/4 to +1/4 of the image width.
	  - y direction: uniformly chosen from -1/4 to +1/4 of the image height.
	
	The annotation is assumed to be in a simple format per line:
		class_id x_center y_center box_width box_height
	where x_center and y_center are given as pixel coordinates.
	"""
	# Read the image.
	img = cv2.imread(image_path)
	if img is None:
		print("Failed to read image:", image_path)
		return
	
	# Get image dimensions.
	height, width = img.shape[:2]
	
	# Determine maximum translation amounts.
	max_tx = width / 4.0  # maximum translation in x direction.
	max_ty = height / 4.0  # maximum translation in y direction.
	
	# Randomly select translation values (they can be negative or positive).
	tx = random.uniform(-max_tx, max_tx)
	ty = random.uniform(-max_ty, max_ty)
	
	# Define translation matrix.
	M = np.float32([[1, 0, tx],
					[0, 1, ty]])
	
	# Apply translation using cv2.warpAffine. The resulting image is kept at original dimensions.
	translated_img = cv2.warpAffine(img, M, (width, height))
	cv2.imwrite(out_image_path, translated_img)
	
	# If the annotation file exists, update the coordinates.
	if os.path.exists(annotation_path):
		new_lines = []
		with open(annotation_path, 'r') as f:
			for line in f:
				parts = line.strip().split()
				# Check if the line has the expected format.
				if len(parts) == 5:
					class_id, x_center, y_center, box_w, box_h = parts
					# Update the center coordinates by adding the translation offsets.
					x_center = (float(x_center) + (tx/width))
					y_center = (float(y_center) + (ty/height))
					new_line = f"{class_id} {x_center:.2f} {y_center:.2f} {box_w} {box_h}"
					new_lines.append(new_line)
				else:
					# If the line doesn't match the expected format, copy it unchanged.
					new_lines.append(line.strip())
		with open(out_annotation_path, 'w') as f:
			f.write("\n".join(new_lines))
	
	print(f"Processed translation augmentation: {out_image_path} with translation (tx={tx:.2f}, ty={ty:.2f})")

	
# Process images in each stage.
stages = [f"stage_{i}" for i in range(N_STAGES)]
for stage in stages:
	in_image_folder = os.path.join(base_dir_images, stage)
	in_annotation_folder = os.path.join(base_dir_annotations, stage)
	out_image_folder = os.path.join(out_base_images, stage)
	out_annotation_folder = os.path.join(out_base_annotations, stage)
	
	os.makedirs(out_image_folder, exist_ok=True)
	os.makedirs(out_annotation_folder, exist_ok=True)
	
	# Select image files (filtering out already augmented ones that include "_translate").
	image_files = [f for f in os.listdir(in_image_folder)
				   if f.lower().endswith(".jpg") and "_translate" not in f]
	
	for filename in image_files:
		image_path = os.path.join(in_image_folder, filename)
		base_filename = os.path.splitext(filename)[0]
		annotation_filename = base_filename + ".txt"
		annotation_path = os.path.join(in_annotation_folder, annotation_filename)
		
		out_image_filename = f"{base_filename}_translate.jpg"
		out_annotation_filename = f"{base_filename}_translate.txt"
		out_image_path = os.path.join(out_image_folder, out_image_filename)
		out_annotation_path = os.path.join(out_annotation_folder, out_annotation_filename)
		
		# Apply the random translation augmentation.
		random_translate_and_update_annotation(image_path, annotation_path, out_image_path, out_annotation_path)

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt

def show_image_with_bbox(filename, bbox):
	"""
	Display an image with a bounding box drawn on it.

	Parameters:
	- filename: str, path to the image file.
	- bbox: tuple of (class_id, x_center, y_center, width, height) in YOLO format (all normalized).
	"""
	# Load the image
	image = cv2.imread(filename)
	if image is None:
		print(f"Error: Unable to load image at {filename}")
		return

	# Get image dimensions (height, width)
	h, w, _ = image.shape

	# Convert YOLO normalized coordinates to absolute pixel values
	class_id, x_center, y_center, box_width, box_height = bbox
	x_center_pixel = x_center * w
	y_center_pixel = y_center * h
	box_width_pixel = box_width * w
	box_height_pixel = box_height * h

	# Calculate top-left and bottom-right coordinates of the bounding box
	x1 = int(x_center_pixel - box_width_pixel / 2)
	y1 = int(y_center_pixel - box_height_pixel / 2)
	x2 = int(x_center_pixel + box_width_pixel / 2)
	y2 = int(y_center_pixel + box_height_pixel / 2)

	# Convert image color from BGR (OpenCV default) to RGB for matplotlib
	image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

	# Draw the bounding box (red color, thickness 2)
	cv2.rectangle(image_rgb, (x1, y1), (x2, y2), (255, 0, 0), 2)

	# Optionally add the class id as text above the bounding box
	label = str(int(class_id))
	cv2.putText(image_rgb, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)

	# Display the image with matplotlib
	plt.figure(figsize=(8, 8))
	plt.imshow(image_rgb)
	plt.axis('off')
	plt.title("Image with Bounding Box")
	plt.show()

# Example usage
# 0.173398437
if __name__ == "__main__":
	image_filename = "/Users/georgye/Documents/repos/ethz/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_case_render_4_rot20.jpg"  # Replace with your image file path
	bounding_box_filename = "/Users/georgye/Documents/repos/ethz/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_case_render_4_rot20.txt"
	for stage in os.listdir("/Users/georgye/Documents/repos/ethz/dslab25/training/vacuum_pump/images/augmented"):
		if stage != "stage_1":
			continue
		for filename in os.listdir(os.path.join("/Users/georgye/Documents/repos/ethz/dslab25/training/vacuum_pump/images/augmented", stage)):
			if filename.endswith(".jpg"):
				image_filename = os.path.join("/Users/georgye/Documents/repos/ethz/dslab25/training/vacuum_pump/images/augmented", stage, filename)
				bounding_box_filename = os.path.join("/Users/georgye/Documents/repos/ethz/dslab25/training/vacuum_pump/annotation/augmented", stage, filename.replace(".jpg", ".txt"))
				with open(bounding_box_filename, 'r') as f:
					bbox_info = f.read().strip().split()
					bbox_info = (0, float(bbox_info[1]), float(bbox_info[2]), float(bbox_info[3]), float(bbox_info[4]))
					print(bounding_box_filename)
					show_image_with_bbox(image_filename, bbox_info)

# 1: x 0.317216797 0.670823568 0.5 0.51
# 2: x 0.490615234 0.670823568 0.5 0.51
# 3: x 0.664013671 0.670823568 0.5 0.51
# 4: x 0.317216797 0.497425131 0.5 0.51
# 5: x 0.490615234 0.497425131 0.5 0.51
# 6: x 0.664013671 0.497425131 0.5 0.51
# 7: x 0.317216797 0.324026694 0.5 0.51
# 8: x 0.490615234 0.324026694 0.5 0.51
# 9: x 0.664013671 0.324026694 0.5 0.51
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 55
#      53 image_filename = "/Users/georgye/Documents/repos/ethz/dslab25/training/vacuum_pump/images/augmented/stage_0/stage_0_case_render_4_rot20.jpg"  # Replace with your image file path
#      54 bounding_box_filename = "/Users/georgye/Documents/repos/ethz/dslab25/training/vacuum_pump/annotation/augmented/stage_0/stage_0_case_render_4_rot20.txt"
# ---> 55 for stage in os.listdir("/Users/georgye/Documents/repos/ethz/dslab25/training/vacuum_pump/images/augmented"):
#      56 	if stage != "stage_1":
#      57 		continue
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/georgye/Documents/repos/ethz/dslab25/training/vacuum_pump/images/augmented'

# %% [markdown]
# # Rename stuff from roboflow (Not used)

# %%
import os
import re

def rename_files_in_folder(folder_path):
	pattern = re.compile(r"(.*)_jpg\.rf\.[a-f0-9]+\.jpg$")

	for filename in os.listdir(folder_path):
		if filename.endswith(".txt"):
			match = pattern.match(filename)
			if match:
				new_filename = f"{match.group(1)}.txt"
				old_path = os.path.join(folder_path, filename)
				new_path = os.path.join(folder_path, new_filename)
				os.rename(old_path, new_path)
				print(f"Renamed: {filename} -> {new_filename}")

# Example usage
folder = "/Users/georgye/Documents/repos/ethz/dslab25/obj_detection/preprocessing/stage_0/images"
rename_files_in_folder(folder)

# %%
import os
import re
import shutil

def rename_and_duplicate(folder_path):
	# Regex pattern to match files like stage_x_case_render_n.txt
	pattern = re.compile(r"^(stage_\d+)_case_render_(\d+)\.txt$")
	
	for filename in os.listdir(folder_path):
		match = pattern.match(filename)
		if match:
			stage, render = match.groups()
			original_path = os.path.join(folder_path, filename)
			
			# New filenames
			new_name_var_0 = f"{stage}_var_0_case_render_{render}.txt"
			new_name_var_1 = f"{stage}_var_1_case_render_{render}.txt"
			path_var_0 = os.path.join(folder_path, new_name_var_0)
			path_var_1 = os.path.join(folder_path, new_name_var_1)

			# Rename original file to var_0
			os.rename(original_path, path_var_0)
			print(f"Renamed: {filename} -> {new_name_var_0}")
			
			# Duplicate to var_1
			shutil.copy(path_var_0, path_var_1)
			print(f"Duplicated: {new_name_var_0} -> {new_name_var_1}")
rename_and_duplicate('/Users/georgye/Documents/repos/ethz/dslab25/assets/vacuum_pump/rendered/anno/stage_6')
# Out:
# Renamed: stage_6_case_render_3.txt -> stage_6_var_0_case_render_3.txt
# Duplicated: stage_6_var_0_case_render_3.txt -> stage_6_var_1_case_render_3.txt
# Renamed: stage_6_case_render_2.txt -> stage_6_var_0_case_render_2.txt
# Duplicated: stage_6_var_0_case_render_2.txt -> stage_6_var_1_case_render_2.txt
# Renamed: stage_6_case_render_1.txt -> stage_6_var_0_case_render_1.txt
# Duplicated: stage_6_var_0_case_render_1.txt -> stage_6_var_1_case_render_1.txt
# Renamed: stage_6_case_render_5.txt -> stage_6_var_0_case_render_5.txt
# Duplicated: stage_6_var_0_case_render_5.txt -> stage_6_var_1_case_render_5.txt
# Renamed: stage_6_case_render_4.txt -> stage_6_var_0_case_render_4.txt
# Duplicated: stage_6_var_0_case_render_4.txt -> stage_6_var_1_case_render_4.txt
# Renamed: stage_6_case_render_6.txt -> stage_6_var_0_case_render_6.txt
# Duplicated: stage_6_var_0_case_render_6.txt -> stage_6_var_1_case_render_6.txt
# Renamed: stage_6_case_render_7.txt -> stage_6_var_0_case_render_7.txt
# Duplicated: stage_6_var_0_case_render_7.txt -> stage_6_var_1_case_render_7.txt
# Renamed: stage_6_case_render_9.txt -> stage_6_var_0_case_render_9.txt
# Duplicated: stage_6_var_0_case_render_9.txt -> stage_6_var_1_case_render_9.txt
# Renamed: stage_6_case_render_8.txt -> stage_6_var_0_case_render_8.txt
# Duplicated: stage_6_var_0_case_render_8.txt -> stage_6_var_1_case_render_8.txt
